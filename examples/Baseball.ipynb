# %% [markdown]
# <hr />
#
# # Baseball App Example
#
# In this example we use Pandas, sklearn, and Bokeh to explore the Lahman Baseball Statistics database.

# %%
## import statements
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import bokeh
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f8712727-2b37-4149-9bc3-68b8e4e28664">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Read data and explore

# %%
import sqlite3
con = sqlite3.connect("../data/baseball/lahman2013.sqlite")

with con:
    cur = con.cursor()
    cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
    data = cur.fetchall()
print([datum[0] for datum in data])
# Out:
# ['AllstarFull', 'Appearances', 'AwardsManagers', 'AwardsPlayers', 'AwardsShareManagers', 'AwardsSharePlayers', 'Batting', 'BattingPost', 'Fielding', 'FieldingOF', 'FieldingPost', 'HallOfFame', 'Managers', 'ManagersHalf', 'Master', 'Pitching', 'PitchingPost', 'Salaries', 'Schools', 'SchoolsPlayers', 'SeriesPost', 'Teams', 'TeamsFranchises', 'TeamsHalf', 'temp']

# %%
# Read sqlite query results into a pandas DataFrame
with con:
    df_salaries = pd.read_sql_query("SELECT * from Salaries", con)

# verify that result of SQL query is stored in the dataframe
print(df.head())
# Out:
#    yearID teamID lgID   playerID    salary
# 0    1985    ATL   NL  barkele01  870000.0
# 1    1985    ATL   NL  bedrost01  550000.0
# 2    1985    ATL   NL  benedbr01  545000.0
# 3    1985    ATL   NL   campri01  633333.0
# 4    1985    ATL   NL  ceronri01  625000.0

# %%
list(df_salaries.teamID.unique())
# Out:
# ['ATL',
#  'BAL',
#  'BOS',
#  'CAL',
#  'CHA',
#  'CHN',
#  'CIN',
#  'CLE',
#  'DET',
#  'HOU',
#  'KCA',
#  'LAN',
#  'MIN',
#  'ML4',
#  'MON',
#  'NYA',
#  'NYN',
#  'OAK',
#  'PHI',
#  'PIT',
#  'SDN',
#  'SEA',
#  'SFN',
#  'SLN',
#  'TEX',
#  'TOR',
#  'COL',
#  'FLO',
#  'ANA',
#  'ARI',
#  'MIL',
#  'TBA',
#  'LAA',
#  'WAS',
#  'MIA']

# %%
gb = df_salaries.groupby('teamID')
salary_by_team = gb['salary'].agg([np.mean, np.std, np.max, np.min] )
salary_by_team['ratio'] = salary_by_team.amax / salary_by_team.amin

# %%
salary_by_team.head()
# Out:
#                 mean           std        amax      amin       ratio
# teamID
# ANA     1.895109e+06  2.667147e+06  13166667.0  150000.0   87.777780
# ARI     2.428196e+06  2.971520e+06  16000000.0  170000.0   94.117647
# ATL     2.130475e+06  3.373518e+06  16061802.0   60000.0  267.696700
# BAL     1.785712e+06  2.491109e+06  17000000.0   60000.0  283.333333
# BOS     2.692114e+06  3.861802e+06  22500000.0   60000.0  375.000000

# %%
salary_by_team.index
# Out:
# Index(['ANA', 'ARI', 'ATL', 'BAL', 'BOS', 'CAL', 'CHA', 'CHN', 'CIN', 'CLE',
#        'COL', 'DET', 'FLO', 'HOU', 'KCA', 'LAA', 'LAN', 'MIA', 'MIL', 'MIN',
#        'ML4', 'MON', 'NYA', 'NYN', 'OAK', 'PHI', 'PIT', 'SDN', 'SEA', 'SFN',
#        'SLN', 'TBA', 'TEX', 'TOR', 'WAS'],
#       dtype='object', name='teamID')

# %%
salary_by_team['teamID'] = salary_by_team.index

# %%
df = salary_by_team.sort('mean')
source = ColumnDataSource(df)
p = bokeh.plotting.figure(x_range=list(df.index))
p.scatter(x="teamID", y="mean", source=source)
show(p)
# Out:
# /Users/aterrel/miniconda/envs/pydata101/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
attributes":{"plot":{"id":"8f732dee-7dc0-44cc-ade4-e7d3b348d561","subtype":"Figure","type":"Plot"}},"id":"79422561-ab28-4016-8fd9-a10415b9ed68","type":"ResetTool"},{"attributes":{"overlay":{"id":"8d909326-efe8-4ba5-b47a-32d3750bcff0","type":"BoxAnnotation"},"plot":{"id":"8f732dee-7dc0-44cc-ade4-e7d3b348d561","subtype":"Figure","type":"Plot"}},"id":"5c25c112-2241-441a-9f21-1f62a9dcdae5","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"cf2ff44c-c3a4-457a-a04e-27b24466ebb8","subtype":"Figure","type":"Plot"}},"id":"21435da7-4b9c-42af-8c42-733376acdcab","type":"WheelZoomTool"},{"attributes":{"data_source":{"id":"caab3446-10ec-4caa-ab17-b90a0892af82","type":"ColumnDataSource"},"glyph":{"id":"ba2e7dbe-b57e-44bf-a954-ba2b09ef422b","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"cbb51fcb-e97d-410a-8b29-4d357ce2585b","type":"Circle"},"selection_glyph":null},"id":"f67c01b3-4152-4302-b0de-6093caedac08","type":"GlyphRenderer"},{"attributes":{},"id":"77bfeba0-af7d-4c38-877a-e6cf910cd9b5","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["ratio","teamID","std","amax","amin","mean"],"data":{"amax":[5875000.0,11500000.0,5375000.0,16500000.0,14936667.0,13000000.0,13500000.0,15505142.0,23000000.0,15000000.0,10125000.0,18910655.0,19369019.0,19700000.0,17000000.0,22000000.0,13166667.0,16333327.0,20557143.0,20275000.0,23000000.0,17000000.0,22250000.0,25000000.0,15500000.0,16061802.0,19000000.0,16571429.0,23145011.0,23854494.0,16000000.0,22500000.0,19000000.0,33000000.0,26187500.0],"amin":[60000.0,60000.0,60000.0,0.0,50000.0,60000.0,60000.0,60000.0,60000.0,60000.0,170000.0,60000.0,60000.0,60000.0,60000.0,60000.0,150000.0,60000.0,60000.0,109000.0,60000.0,50000.0,60000.0,60000.0,170000.0,60000.0,60000.0,316000.0,60000.0,60000.0,170000.0,60000.0,480000.0,0.0,316000.0],"mean":[613243.5800524935,707458. ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[41]</strong>&gt;</code></p>

# %% [markdown]
# Hmm, can't read the y axis very well...

# %%
df = df.sort('mean')
source = ColumnDataSource(df)
p = figure(x_range=list(df["teamID"]))
p.scatter(x="teamID", y="mean", source=source)
p.xaxis.major_label_orientation = np.pi/3

show(p)
# Out:
# /Users/aterrel/miniconda/envs/pydata101/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="plotdiv" id="129da965-1fa3-4a27-94e2-bcefd64aded3"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("129da965-1fa3-4a27-94e2-bcefd64aded3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '129da965-1fa3-4a27-94e2-bcefd64aded3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5d46f5e3-6b0b-46eb-a734-015cb4b8eb86":{"roots":{"references":[{"attributes":{},"id":"111b034e-7653-45d7-9559-5ee3a5da4a51","type":"CategoricalTickFormatter"},{"attributes":{"formatter":{"id":"77bfeba0-af7d-4c38-877a-e6cf910cd9b5","type":"BasicTickFormatter"},"plot":{"id":"8f732dee-7dc0-44cc-ade4-e7d3b348d561","subtype":"Figure","type":"Plot"},"ticker":{"id":"f7c8cbde-63c8-472d-a26c-c67eec5b55ce","type":"BasicTicker"}},"id":"a948b989-a93b-4fa3-9
...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[43]</strong>&gt;</code></p>

# %% [markdown]
# Let's view a max versus ratio

# %%
TOOLS = "pan,wheel_zoom,box_zoom,reset,save,lasso_select"

df.sort_values('mean', inplace=True)
source = ColumnDataSource(df)
s1 = figure(title="Pay Avg",x_range=source.data["teamID"], tools=TOOLS, width=500)
s1.scatter(x="teamID", y="mean", source=source)
s1.xaxis.major_label_orientation = np.pi/3

s2 = figure(title="Pay Ratio", x_range=s1.x_range, tools=TOOLS, width=500)
s2.scatter(x="teamID", y="ratio", source=source)
s2.xaxis.major_label_orientation = np.pi/3

p = gridplot([[s1, s2]])
show(p)
# Out:
#     <div class="plotdiv" id="6a8fc388-39f8-4663-abc9-c376c309e919"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6a8fc388-39f8-4663-abc9-c376c309e919");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6a8fc388-39f8-4663-abc9-c376c309e919' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"6e8f30da-9c04-4260-b46f-7bddc73feb1c":{"roots":{"references":[{"attributes":{"callback":null},"id":"50b547d0-7a29-4bcd-95db-bbaef3d91ef9","type":"DataRange1d"},{"attributes":{},"id":"111b034e-7653-45d7-9559-5ee3a5da4a51","type":"CategoricalTickFormatter"},{"attributes":{"formatter":{"id":"77bfeba0-af7d-4c38-877a-e6cf910cd9b5","type":"BasicTickFormatter"},"plot":{"id":"8f732dee-7dc0-44cc-ade4-e7d3b348d561","subtype":"Figure","type":"Plot"},"ticker":{"id":"f7c8cbde-63c8-472d-a26c-c67eec5b55ce","type":"BasicTicker"}},"id":"a948b989-a93b-4fa3-9c06-38c50b7ac442","type":"LinearAxis"},{"attributes":{"overlay":{"id":"7481ec1d-374a-429a-8efb-6ae70885de5c","type":"BoxAnnotation"},"plot":{"id":"3bf8def4-9c4e-41f0-b0c9-169a096433e3","subtype":"Figure","type":"Plot"}},"id":"d3a91808-1649-40a8-a67f-fbd6f88c170e","type":"BoxZoomTool"},{"attributes":{},"id":"2978fe41-4da5-46d5-9318-037e4679acac","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"96130cd2-6139-4df2-ab4c-8d06c3bc1b78","subtype":"Figure","type":"Plot"},"ticker":{"id":"98bae55c-7f87-441e-b095-9cfa7b00e258","type":"CategoricalTicker"}},"id":"c4f0635e-6fb1-4823-a19d-17735fc3a9d1","type":"Grid"},{"attributes":{"plot":{"id":"8f732dee-7dc0-44cc-ade4-e7d3b348d561","subtype":"Figure","type":"Plot"}},"id":"79422561-ab28-4016-8fd9-a10415b9ed68","type":"ResetTool"},{"attributes":{"formatter":{"id":"336b9cb7-e5ba-4343-863a-5ee508cad8a7","type":"CategoricalTickFormatter"},"major_label_orientation":1.0471975511965976,"plot":{"id":"3bf8def4-9c4e-41f0-b0c9-169a096433e3","subtype":"Figure","type":"Plot"},"ticker":{"id":"8eedf64b-ddbf-4168-8e48-e86122d23a3a","type":"CategoricalTicker"}},"id":"8921218c-357a-4d63-b910-fd40afdd2039","type":"CategoricalAxis"},{"attributes":{"below":[{"id":"25bddef2-a9fa-4e0e-a9ce-71990570453b","type":"CategoricalAxis"}],"left":[{"id":"22e2562c-3582-4781-b821-9969c2b048ba","type":"LinearAxis"}],"plot_width":500,"renderers":[{"id":"25bddef2-a9fa-4e0e-a9ce-71990570453b","type":"CategoricalAxis"},{"id":"65d34113-392f-4114-83db-4f94c1ef52b4","type":"Grid"},{"id":"22e2562c-3582-4781-b821-9969c2b048ba","type":"LinearAxis"},{"id":"36ec3161-0c7b-4a71-a61a-d6b52cee8714","type":"Grid"},{"id":"65cfd346-ead9-42eb-b863-9c593df49e59","type":"BoxAnnotation"},{"id":"cce7a28a-8300-487b-9ccd-f12ad027c36f","type":"PolyAnnotation"},{"id":"59d06fa1-f45a-47d5-a345-b8de20f724ff","type":"GlyphRenderer"}],"title":"Pay Avg","tool_events":{"id":"faa25b4b-4b0a-4201-8eb7-698c2ae37cb4","type":"ToolEvents"},"tools":[{"id":"f17485bb-3a73-443c-afcc-7991a4220d92","type":"PanTool"},{"id":"a168cdbc-309e-4109-8aa7-172c6c6b71f6","type":"WheelZoomTool"},{"id":"307a398e-0488-4d28-9e50-c1e6232d9398","type":"BoxZoomTool"},{"id":"b0b256d0-587c-450b-a6ca-a31ffe6d7117","type":"ResetTool"},{"id":"36293513-96c8-41ee-9e68-4f50e01dce68","type":"PreviewSaveTool"},{"id":"61d9f172-3d7c-4c4b-a1da-d6a3f2bd5221","type":"LassoSelectTool"}],"x_range":{"id":"2521dfac-4a04-4798-9df3-9673a1827e2b","type":"FactorRange"},"y_range":{"id":"35a5e047-8ed0-4e3c-9d7c-8d2bbe8eaf83","type":"DataRange1d"}},"id":"45ccc649-ceda-4bed-af85-77a42af06be0","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"1da13e05-1855-470c-8e89-45a265fd9a36","subtype":"Figure","type":"Plot"},"ticker":{"id":"b1cde824-8733-4ce0-9c04-d6cb10eb8ea9","type":"CategoricalTicker"}},"id":"1c5ccb75-3be6-4913-8741-6159545dac14","type":"Grid"},{"attributes":{},"id":"060a1346-dfb0-4679-a787-e3780ba037ca","type":"BasicTicker"},{"attributes":{"plot":{"id":"0ea851cf-e0db-482c-9361-91aa0ca71b56","subtype":"Figure","type":"Plot"}},"id":"59bd3e2c-d7c1-4975-845c-ea8583e95258","type":"ResizeTool"},{"attributes":{"callback":null,"column_names":["ratio","all_stars","teamID","std","amax","amin","mean"],"data":{"all_stars":[11.62621359223301,11.16504854368932,10.70388349514563,11.699029126213592,12.014563106796118,10.339805825242719,12.572815533980583,10.922330097087379,15.703883495145632,10.825242718446601,11.966019417475728,10.8 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[153]</strong>&gt;</code></p>

# %% [markdown]
# <hr/>
#
# Now let's join on the AllStars table to see how max salaries and all star count correlate.

# %%
with con:
    df_allstar = pd.read_sql_query("SELECT * from AllstarFull", con)

# %%
df_allstar.head()
# Out:
#     playerID  yearID  gameNum        gameID teamID lgID   GP  startingPos
# 0  aaronha01    1955        0  NLS195507120    ML1   NL  1.0          NaN
# 1  aaronha01    1956        0  ALS195607100    ML1   NL  1.0          NaN
# 2  aaronha01    1957        0  NLS195707090    ML1   NL  1.0          9.0
# 3  aaronha01    1958        0  ALS195807080    ML1   NL  1.0          9.0
# 4  aaronha01    1959        1  NLS195907070    ML1   NL  1.0          9.0

# %%
df_allstar_count = df_allstar.groupby('teamID')['playerID'].agg(np.count_nonzero)

# %%
df_allstar_count.head()
# Out:
# teamID
# ANA     14
# ARI     33
# ARL      1
# ATL    134
# BAL    169
# Name: playerID, dtype: int64

# %%
df_allstar_count[df_allstar_count == df_allstar_count.max()]
# Out:
# teamID
# NYA    412
# Name: playerID, dtype: int64

# %% [markdown]
# Now let's use this as the size of the circles in the scatter plot

# %%
df_allstar_count_circle_size = 10 * df_allstar_count / df_allstar_count.max() + 10

# %% [markdown]
# <hr/>
#
# Now lets join the data to all_star sizes

# %%
df = pd.DataFrame()

# %%
df = df.append(salary_by_team)

# %%
salary_by_team['all_stars'] = df_allstar_count_circle_size

# %%
df.append?

# %%
df.head()
# Out:
#                 mean           std        amax      amin       ratio  \
# teamID
# ANA     1.895109e+06  2.667147e+06  13166667.0  150000.0   87.777780
# ARI     2.428196e+06  2.971520e+06  16000000.0  170000.0   94.117647
# ATL     2.130475e+06  3.373518e+06  16061802.0   60000.0  267.696700
# BAL     1.785712e+06  2.491109e+06  17000000.0   60000.0  283.333333
# BOS     2.692114e+06  3.861802e+06  22500000.0   60000.0  375.000000
#
#         all_stars
# teamID
# ANA     10.339806
# ARI     10.800971
# ATL     13.252427
# BAL     14.101942
# BOS     16.917476

# %%
r = bz.join(bz.Data(df1), bz.Data(df), 'teamID')
r.head()

# %%
df = salary_by_team.sort("amax")
print(df.head())
source = ColumnDataSource(df)
p = figure(x_range=list(df["teamID"]))
p.scatter(x="teamID", y="amax", size="all_stars", source=source, fill_alpha=0.5, )
p.xaxis.major_label_orientation = np.pi/3

show(p)
# Out:
#                 mean           std        amax      amin       ratio  \
# teamID
# CAL     7.390732e+05  9.606285e+05   5375000.0   60000.0   89.583333
# ML4     6.132436e+05  8.535337e+05   5875000.0   60000.0   97.916667
# TBA     1.528400e+06  2.011091e+06  10125000.0  170000.0   59.558824
# MON     7.074589e+05  1.192678e+06  11500000.0   60000.0  191.666667
# KCA     1.299026e+06  1.951653e+06  13000000.0   60000.0  216.666667
#
#         all_stars teamID
# teamID
# CAL     11.626214    CAL
# ML4     11.165049    ML4
# TBA     10.703883    TBA
# MON     11.699029    MON
# KCA     12.014563    KCA
# /Users/aterrel/miniconda/envs/pydata101/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     <div class="plotdiv" id="bda6a4a4-fa46-4ffb-aa6a-eaa2ef2becf5"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bda6a4a4-fa46-4ffb-aa6a-eaa2ef2becf5");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bda6a4a4-fa46-4ffb-aa6a-eaa2ef2becf5' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"02784b67-9036-4d79-8f71-436d779ca0c0":{"roots":{"references":[{"attributes":{},"id":"2ec75866-a138-4e86-bba3-8199c6b7b1a7","type":"BasicTicker"},{"attributes":{},"id":"111b034e-7653-45d7-9559-5ee3a5da4a51","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"9925d7f1-f66d-4f31-971b-30efbd5bbec8","subtype":"Figure","type":"Plot"}},"id":"42da7a99-384b-451d-bb43-1cdf99bf43d4","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":
...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[78]</strong>&gt;</code></p>

# %% [markdown]
# <hr/>
#
# Now let's make this an interactive plot!

# %%
# Read sqlite query results into a pandas DataFrame
with con:
    df_salaries = pd.read_sql_query("SELECT yearID, teamID, salary from Salaries", con)
    df_allstar = pd.read_sql_query("SELECT yearID, teamID, playerID from AllstarFull", con)

def compute_df(year=2012):
    salaries_for_year = df_salaries[ df_salaries.yearID == year]
    max_salaries = salaries_for_year.groupby('teamID')['salary'].agg([np.max])
    max_salaries.sort_values('amax', ascending=False, inplace=True)
    allstar_for_year = df_allstar[ df_allstar.yearID == year]
    allstar_count = allstar_for_year.groupby('teamID')['playerID'].count()
    allstar_count_circle_size = 10 * allstar_count / allstar_count.max() + 10
    result = pd.DataFrame(max_salaries)
    result['all_stars']= allstar_count_circle_size
    result['teamID'] = result.index
    return result

# %%
compute_df().head()
# Out:
#               amax  all_stars teamID
# teamID
# NYA     30000000.0  14.444444    NYA
# LAA     24187500.0  12.222222    LAA
# NYN     23145011.0  13.333333    NYN
# MIN     23000000.0  11.111111    MIN
# DET     23000000.0  15.555556    DET

# %%
source = ColumnDataSource(compute_df())
p = figure(x_range=list(source.data["teamID"]))
p.scatter(x="teamID", y="amax", size="all_stars", source=source, fill_alpha=0.5, )
p.xaxis.major_label_orientation = np.pi/3

# %%
from ipywidgets import interact, widgets 
def update(year):
    df = compute_df(year)
    source.data['all_stars'] = df['all_stars']
    source.data['amax'] = df['amax']
    bokeh.io.push_notebook()

# %%
show(p)
# Out:
#     <div class="plotdiv" id="db9f48a4-e0dd-4fa0-be2e-6d79ab9b9e28"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("db9f48a4-e0dd-4fa0-be2e-6d79ab9b9e28");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'db9f48a4-e0dd-4fa0-be2e-6d79ab9b9e28' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"84150fa8-c5bb-42be-bbee-279b5de08c45":{"roots":{"references":[{"attributes":{},"id":"2ec75866-a138-4e86-bba3-8199c6b7b1a7","type":"BasicTicker"},{"attributes":{},"id":"111b034e-7653-45d7-9559-5ee3a5da4a51","type":"CategoricalTickFormatter"},{"attributes":{"formatter":{"id":"77bfeba0-af7d-4c38-877a-e6cf910cd9b5","type":"BasicTickFormatter"},"plot":{"id":"8f732dee-7dc0-44cc-ade4-e7d3b348d561","subtype":"Figure","type":"Plot"},"ticker":{"id":"f7c8cbde-63c8-472d-a26c-c67eec5b55ce","type":"BasicTicker"}},"id":"a948b989-a93b-4fa3-9c06-38c50b7ac442","type":"LinearAxis"},{"attributes":{},"id":"2978fe41-4da5-46d5-9318-037e4679acac","type":"CategoricalTickFormatter"},{"attributes":{"plot":{"id":"96130cd2-6139-4df2-ab4c-8d06c3bc1b78","subtype":"Figure","type":"Plot"},"ticker":{"id":"98bae55c-7f87-441e-b095-9cfa7b00e258","type":"CategoricalTicker"}},"id":"c4f0635e-6fb1-4823-a19d-17735fc3a9d1","type":"Grid"},{"attributes":{"plot":{"id":"8f732dee-7dc0-44cc-ade4-e7d3b348d561","subtype":"Figure","type":"Plot"}},"