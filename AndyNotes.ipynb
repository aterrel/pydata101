# %% [markdown]
# # PyData 101 Essential Data Skills for Python Hackers
#
#
# This notebook is Andy's preparations for the pydata101 tutoral at PyCon2016. It is unedited which means incomplet, unedittted, and probably inackurate. Please read a more polished version without this heading.

# %% [markdown]
# <hr/>

# %% [markdown]
# ## import statements
#
# Let's start with a few important import statements. Notice there are some conventions here in naming the packages. Often you will run across code using this conventions so I thought I would use them here.
#
# Additionally we are using a feature that plots all our output into this notebook. This is a preference and by no means necessary, but we like to have everything inline. By using the `%matplotlib inline` that the top of the next cell all our plots based on the matplotlib package will be inline. By using `output_notebook` from bokeh we have the same effect for its plots.

# %%
# %matplotlib inline 
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import bokeh
from bokeh.io import output_notebook, show
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d89b9a2e-11d8-48c8-ade4-0ef8e4f02b87">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Here's the versions of the libraries I'm using. You might see if they match your own.

# %%
print("Numpy version: {}".format(np.__version__))
print("Pandas version: {}".format(pd.__version__))
print("MatPlotLib version: {}".format(mpl.__version__))
print("Seaborn version: {}".format(sns.__version__))
print("Scikit-Learn version: {}".format(sklearn.__version__))
print("Bokeh version: {}".format(bokeh.__version__))
# Out:
# Numpy version: 1.11.0
# Pandas version: 0.18.1
# MatPlotLib version: 1.5.1
# Seaborn version: 0.7.0
# Scikit-Learn version: 0.17.1
# Bokeh version: 0.11.1

# %%
sns.set(color_codes=True)
sns.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5, "figure.figsize": (20, 12)})
label_size = 24
mpl.rcParams['xtick.labelsize'] = mpl.rcParams['ytick.labelsize'] = label_size 
mpl.rcParams['axes.labelsize'] = label_size

# %% [markdown]
# <hr/>

# %% [markdown]
# ## Loading some data
#
# We have some data from an [Amazon Product](http://jmcauley.ucsd.edu/data/amazon/) scrape by [Julian McAuley](http://cseweb.ucsd.edu/~jmcauley/). If you use this data please cite Julian!
#
# Let's see what we have, note we can use some bash commands in Jupyter by starting a line with `!`

# %%
! ls -al data
# Out:
# total 0
# drwxr-xr-x   5 aterrel  staff  170 May 16 12:03 .
# drwxr-xr-x  10 aterrel  staff  340 May 21 21:53 ..
# drwxr-xr-x  24 aterrel  staff  816 May 16 12:02 qa
# drwxr-xr-x   3 aterrel  staff  102 May 16 12:02 ratings
# drwxr-xr-x   4 aterrel  staff  136 May 16 12:03 reviews

# %% [markdown]
# But in reality you don't have to us it for some commands like `ls` and `cd`

# %%
ls -alh data/reviews/
# Out:
# total 41951064
# drwxr-xr-x  4 aterrel  staff   136B May 16 12:03 ./
# drwxr-xr-x  5 aterrel  staff   170B May 16 12:03 ../
# -rw-r--r--  1 aterrel  staff    20G Feb 17 17:20 complete.json.gz
# -rw-r--r--@ 1 aterrel  staff    45M May 16 11:21 reviews_Clothing_Shoes_and_Jewelry_5.json.gz

# %% [markdown]
# The complete data is pretty large, but the individual departments are not so bad. But let's try to get a feel for how to build this data:

# %%
# !gzcat data/reviews/reviews_Clothing_Shoes_and_Jewelry_5.json.gz | head -2
# Out:
# {"reviewerID": "A1KLRMWW2FWPL4", "asin": "0000031887", "reviewerName": "Amazon Customer \"cameramom\"", "helpful": [0, 0], "reviewText": "This is a great tutu and at a really great price. It doesn't look cheap at all. I'm so glad I looked on Amazon and found such an affordable tutu that isn't made poorly. A++", "overall": 5.0, "summary": "Great tutu-  not cheaply made", "unixReviewTime": 1297468800, "reviewTime": "02 12, 2011"}
# {"reviewerID": "A2G5TCU2WDFZ65", "asin": "0000031887", "reviewerName": "Amazon Customer", "helpful": [0, 0], "reviewText": "I bought this for my 4 yr old daughter for dance class, she wore it today for the first time and the teacher thought it was adorable. I bought this to go with a light blue long sleeve leotard and was happy the colors matched up great. Price was very good too since some of these go for over $15.00 dollars.", "overall": 5.0, "summary": "Very Cute!!", "unixReviewTime": 1358553600, "reviewTime": "01 19, 2013"}
# gzcat: error writing to output: Broken pipe
# gzcat: data/reviews/reviews_Clothing_Shoes_and_Jewelry_5.json.gz: uncompress failed

# %% [markdown]
# Oph! This is JSON Lines not JSON! Let's load it into lines

# %%
import gzip
review_lines = gzip.open('data/reviews/reviews_Clothing_Shoes_and_Jewelry_5.json.gz', 'rt').readlines()
len(review_lines)
# Out:
# 278677

# %% [markdown]
# Now we have something, but it's a lot of lines. So we load it into a `DataFrame`, an object that is the data hacker's go to for manipulating structured data.
#
# Unfortunately, its not as straight forward as `pd.read_json`, since first we have to turn all those JSON strings into Python objects, so let's turn each into a dict and then build a `DataFrame`

# %%
import json
df_reviews = pd.DataFrame(list(map(json.loads, review_lines)))

# %% [markdown]
# Now let's see what we have:

# %%
df_reviews.head()
# Out:
#          asin helpful  overall  \
# 0  0000031887  [0, 0]      5.0
# 1  0000031887  [0, 0]      5.0
# 2  0000031887  [0, 0]      5.0
# 3  0000031887  [0, 0]      5.0
# 4  0000031887  [0, 0]      5.0
#
#                                           reviewText   reviewTime  \
# 0  This is a great tutu and at a really great pri...  02 12, 2011
# 1  I bought this for my 4 yr old daughter for dan...  01 19, 2013
# 2  What can I say... my daughters have it in oran...   01 4, 2013
# 3  We bought several tutus at once, and they are ...  04 27, 2014
# 4  Thank you Halo Heaven great product for Little...  03 15, 2014
#
#        reviewerID                 reviewerName                        summary  \
# 0  A1KLRMWW2FWPL4  Amazon Customer "cameramom"  Great tutu-  not cheaply made
# 1  A2G5TCU2WDFZ65              Amazon Customer                    Very Cute!!
# 2  A1RLQXYNCMWRWN                       Carola       I have buy more than one
# 3   A8U3FAMSJVHS5                      Caromcg               Adorable, Sturdy
# 4  A3GEOILWLK86XM                           CJ        Grammy's Angels Love it
#
#    unixReviewTime
# 0      1297468800
# 1      1358553600
# 2      1357257600
# 3      1398556800
# 4      1394841600

# %% [markdown]
# Okay the overall votes is a number, let's make some statistics about them. First we extract the series object out of the data frame.

# %%
overall = df_reviews['overall']

# %%
overall.describe()
# Out:
# count    278677.000000
# mean          4.245133
# std           1.103747
# min           1.000000
# 25%           4.000000
# 50%           5.000000
# 75%           5.000000
# max           5.000000
# Name: overall, dtype: float64

# %%
plt.figure()
g = sns.distplot(overall, kde=False, bins=5) 
g.set_title("Distribution of Products Overall Rating")

# %% [markdown]
# Let's actually use those helpful votes as well.

# %%
df_reviews['helpful_votes'] = df_reviews['helpful'].apply(lambda row: row[0])
df_reviews['overall_votes'] = df_reviews['helpful'].apply(lambda row: row[1])
df_reviews['percent_helpful'] = df_reviews['helpful_votes'] / df_reviews['overall_votes']
df_reviews['review_helpful'] = np.where((df_reviews.percent_helpful > .7) & (df_reviews.helpful_votes > 5), "Yes", "No")

# %%
df_reviews.describe()
# Out:
# /Users/aterrel/miniconda/envs/pydata101/lib/python3.5/site-packages/numpy/lib/function_base.py:3823: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#              overall  unixReviewTime  helpful_votes  overall_votes  \
# count  278677.000000    2.786770e+05  278677.000000   278677.00000
# mean        4.245133    1.374197e+09       1.145936        1.34460
# std         1.103747    2.904510e+07       6.579834        7.05004
# min         1.000000    1.048896e+09       0.000000        0.00000
# 25%         4.000000    1.362787e+09       0.000000        0.00000
# 50%         5.000000    1.382141e+09       0.000000        0.00000
# 75%         5.000000    1.393200e+09       1.000000        1.00000
# max         5.000000    1.406074e+09    1200.000000     1267.00000
#
#        percent_helpful
# count     87021.000000
# mean          0.780014
# std           0.346846
# min           0.000000
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max           2.000000

# %%
df_reviews['percent_helpful'].dropna().describe()
# Out:
# count    87021.000000
# mean         0.780014
# std          0.346846
# min          0.000000
# 25%          0.666667
# 50%          1.000000
# 75%          1.000000
# max          2.000000
# Name: percent_helpful, dtype: float64

# %%
ph = df_reviews['percent_helpful']

# %%
ph[ph > 1.0]
# Out:
# 30730    2.0
# Name: percent_helpful, dtype: float64

# %%
df_reviews.loc[30730]
# Out:
# asin                                                      B000JD2614
# helpful                                                       [4, 2]
# overall                                                            5
# reviewText         I have been waiting for these to go on sale fo...
# reviewTime                                               02 17, 2009
# reviewerID                                            A353U0L2HAMSHV
# reviewerName                    Cricket "Living life and loving it!"
# summary                                               A gift for me!
# unixReviewTime                                            1234828800
# helpful_votes                                                      4
# overall_votes                                                      2
# percent_helpful                                                    2
# review_helpful                                                    No
# Name: 30730, dtype: object

# %%
ph = ph[ph < 1.1]

# %%
sns.distplot(ph, kde=False, bins=10)

# %% [markdown]
# <hr/>

# %% [markdown]
# # Analyzing the text

# %%
# !python -m textblob.download_corpora
# Out:
# [nltk_data] Downloading package brown to /Users/aterrel/nltk_data...
# [nltk_data]   Unzipping corpora/brown.zip.
# [nltk_data] Downloading package punkt to /Users/aterrel/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /Users/aterrel/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/aterrel/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /Users/aterrel/nltk_data...
# [nltk_data]   Unzipping corpora/conll2000.zip.
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /Users/aterrel/nltk_data...
# [nltk_data]   Unzipping corpora/movie_reviews.zip.
# Finished.

# %%
from textblob import TextBlob

# %%
df_reviews['polarity'] = df_reviews['reviewText'].apply(lambda x: TextBlob(x).sentiment.polarity)

# %%
df_reviews['len_words'] = df_reviews['reviewText'].apply(lambda x: len(TextBlob(x).words))

# %%
df_reviews['len_sentences'] = df_reviews['reviewText'].apply(lambda x: len(TextBlob(x).sentences))

# %%
df_reviews['subjectivity'] = df_reviews['reviewText'].apply(lambda x: TextBlob(x).sentiment.subjectivity)

# %%
df_reviews['words_per_sentence'] = df_reviews.len_words / df_reviews.len_sentences

# %%
df_reviews.plot(kind='scatter', x='percent_helpful', y='len_sentences')

# %%
df_reviews.len_words.hist(bins=200)

# %%
df_reviews.boxplot('polarity', 'overall')

# %%
df_reviews['sentence_complexity'] = df_reviews.reviewText.apply(
    lambda x: float(len(set(TextBlob(x).words))) / len(TextBlob(x).words)
              if len(TextBlob(x).words) > 0 else np.nan)

# %%
# bubbleplot with colour based on a feature and size based on another feature
plt.figure(figsize=(20,10))
plt.scatter(df_new2.overall_votes, df_new2.time_from_first_review, c=df_new2.sentence_complexity, s=df_new2.len_words, alpha=.2)

# %% [markdown]
# Let's first split our data into a training set and test set, below we use a 80/20 split.

# %%
from sklearn.cross_validation import train_test_split
df_train, df_test = train_test_split(df_reviews, test_size=0.2, random_state=0)

# %% [markdown]
# Ok, now that we have our data split into training and test, let's create our word matrix!  We do with the CountVectorizer function

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X_train = vectorizer.fit_transform(df_train.reviewText)

"""What this just did is used our training data and created the word matrix.  Now the next step is to apply this matrix to our test data set.  If the word wasn't seen in the training data set, then it won't be in our word matrix we create for our test data set"""
X_test = vectorizer.transform(df_test.reviewText)
y_test = vec

# %%
"""standard imports"""
from sklearn.linear_model import LogisticRegression

lg = LogisticRegression()
lg.fit(X_train, df_train.review_helpful)

# %%
lg_score = lg.score(X_test, df_test.review_helpful)
"Logistic Regression mean accuracy: " + str(lg_score)
# Out:
# 'Logistic Regression mean accuracy: 0.955737763743'

# %% [markdown]
# Precision: What percentage of our predicted helpful reviews are actually helpful reviews? Aka, when our model says that a review is helpful, what percentage of the time is it actually hepful?
#
# Recall: What percentage of helpful reviews did we actually catch with our model? Example, if there were 1,000 helpful reviews, how many of them did we correctly identify as helpful?

# %%
lg_pred = lg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(df_test.review_helpful, lg_pred)
# Out:
# array([[53068,   449],
#        [ 2018,   201]])

# %%
df = pd.DataFrame(confusion_matrix(df_test.review_helpful, lg_pred),
                  columns=['No', 'Yes'], index=['No', 'Yes'])
sns.heatmap(df / len(lg_pred), annot=True)
plt.title("Logistic Regression Accuracy")
plt.ylabel('actual')
plt.xlabel('predicted')

# %%
len(lg_pred[lg_pred=='Yes']) / len(lg_pred)
# Out:
# 0.01166212142959667

# %%
len(lg_pred[lg_pred=='No']) / len(lg_pred)
# Out:
# 0.9883378785704033

# %%
lg.coef_.shape
# Out:
# (1, 70217)

# %%
X_train.shape
# Out:
# (222941, 70217)

# %%
vectorizer?

# %%
vectorizer.inverse_transform?

# %%
vectorizer.inverse_transform(X_train)
# Out:
# [array(['it', 'just', 'arrived', 'about', '20mins', 'ago', 'which', 'was',
#         'super', 'fast', 'why', 'before', 'due', 'is', 'always', 'plus',
#         'when', 'ordering', 'online', 'however', 'put', 'of', 'the',
#         'package', '1st', 'thing', 'noticed', 'color', 'picture', 'shows',
#         'vibrant', 'candy', 'apple', 'red', 'this', 'deeper', 'more',
#         'velvet', 'shade', 'still', 'beautiful', 'look', 'not', 'expected',
#         'common', 'shopping', 'downside', 'to', 'different', 'shades',
#         'screens', 'then', 'size', 'everyone', 'knows', 'up', 'from',
#         'over', 'seas', 'well', 'for', 'dress', 'don', 'bad', 'idea', 'at',
#         'very', 'least', 'sizes', 'too', 'big', 'also', 'length', '3inches',
#         'longer', 'than', 'shown', 'pretty', 'no', 'snags', 'good',
#         'stitching', 'soft', 'flowy', 'feel', 'neck', 'crimpt',
#         'beautifully', 'will', 'try', 'on', 'soon', 'calculate', 'expense',
#         'fitting', 'versus', 'return', 'post', 'back'],
#        dtype='<U185'),
#  array(['the', 'this', 'very', 'good', 'fitting', 'loved', 'sweater', 'fit',
#         'perfectly', 'love', 'longish', 'arms', 'have', 'and', 'need',
#         'that', 'quality', 'great', 'price', 'friendly', 'company',
#         'ordered', 'large', 'broad', 'shoulders', 'am', '34', '135lbs',
#         'wanted', 'some', 'room', 'they', 'are', 'form', 'in', 'way'],
#        dtype='<U185'),
#  array(['about', 'of', 'the', 'not', 'no', 'will', 'and', 'they', 'are',
#         'in', 'what', 'can', 'one', 'say', 'underwear', 'much', 'but',
#         'here', 'goes', 'comfortable', 'cover', 'my', 'areas', 'itchy',
#         'seams', 'light', 'cool', 'mine', 'came', 'packs', 'various',
#         'colors', 'as', 'advertised', 'enjoying', 'them', 'buy', 'again',
#         'future'],
#        dtype='<U185'),
#  array(['it', 'is', 'of', 'the', 'this', 'size', 'up', 'for', 'too', 'big',
#         'back', 'have', 'that', 'they', 'in', 'but', 'as', 'kind', 'wish',
#         'would', 'sent', 'bigger', 'th', 'thigh', 'if', 'did', 'been',
#         'waist', 'with', 'wear', 'think', 'll', 'loosen'],
#        dtype='<U185'),
#  array(['it', 'just', 'is', 'of', 'the', 'more', 'then', 'too', 'big', 'no',
#         'love', 'way', 'what', 'as', 'would', 'if', 'nice', 'fabric',
#         'design', 'matter', 'description', 'said', 'even', 'bathing',
#         'suit', 'coverup', 'there', 'were', 'only', 'belt', 'or', 'weighed',
#         'like', '50', 'lbs'],
#        dtype='<U185'),
#  array(['just', 'put', 'of', 'the', 'this', 'look', 'to', 'for', 'at',
#         'and', 'in', 'said', 'or', 'like', 'stuff', 'its', 'impossible',
#         'get', 'out', 'you', 'could', 'an', 'idiot', 'counter', 'trying',
#         'your', 'card', 'wallet', 'pay', 'columbia'],
#        dtype='<U185'),
#  array(['always', 'of', 'the', 'more', 'to', 'from', 'well', 'for', 'soft',
#         'and', 'great', 'company', 'they', 'are', 'but', 'buy', 'only',
#         'an', 'another', 'pair', 'socks', 'reliable', 'smooth', 'warm',
#         'wash', 'last', 'almost', 'forever', 'cheap', 'so', 'watch',
#         'sales', 'these', 'want', 'any'],
#        dtype='<U185'),
#  array(['fast', 'always', 'ordering', 'of', 'the', 'picture', 'more', 'to',
#         'at', 'very', 'too', 'also', 'than', 'fit', 'have', 'and',
#         'ordered', 'am', '34', 'they', 'are', 'much', 'if', 'did', 'so',
#         'these', 'pleasantly', 'surprised', 'comfort', 'level', 'shoes',
#         'hard', 'feet', 'concerned', 'especially', 'man', 'made',
#         'materials', 'after', 'reading', 'positive', 'reviews', 'glad',
#         'cute', 'attractive', 'service'],
#        dtype='<U185'),
#  array(['it', 'was', 'is', 'the', 'this', 'for', 'dress', 'soft', 'sweater',
#         'and', 'with', 'lovely', 'wore', 'first', 'time', 'today',
#         'leggings', 'comfy'],
#        dtype='<U185'),
#  array(['it', 'when', 'very', 'love', 'and', 'but', 'my', 'with', 'nice',
#         'or', 'so', 'play', 'alot', 'husband', 'calls', 'worry', 'ring',
#         'im', 'upset', 'nervous', 'do'],
#        dtype='<U185'),
#  array(['it', 'the', 'this', 'to', 'don', 'big', 'back', 'have', 'and',
#         'quality', 'can', 'if', 'waist', 'with', 'wear', 'there', 'belt',
#         'get', 'you', 'your', 'so', 'these', 'want', 'any', 'especially',
#         'high', 'around', 'wide', 'elastic', 'black', 'fuss', 'tying',
#         'laces', 'show', 'off', 'adds', 'class', 'outfit', 'used', 'be',
#         'fat', 'bought', 'all', 'caftans', 'shapeless', 'things', 'now',
#         've', 'dieted', 'regained', 'shape'],
#        dtype='<U185'),
#  array(['the', 'to', 'size', 'for', 'no', 'feel', 'that', 'large', 'with',
#         'wear', 'said', 'were', 'like', 'could', 'these', 'shoes',
#         'reviews', 'disagree', 'run', '10', 'received', 'true', 'liked',
#         'slight', 'arch', 'support', 'hours', 'pain'],
#        dtype='<U185'),
#  array(['it', 'was', 'of', 'the', 'this', 'not', 'size', 'for', 'and',
#         'great', 'ordered', 'one', 'but', 'would', 'did', 'with', 'nice',
#         'fabric', 'an', 'your', 'last', 'these', 'time', 'be', 'order',
#         'shirts', 'happy', 'heavy', 'weight', 'pockets', 'unfortunately',
#         'took', 'advice', 'other', 'reviewers', 'smaller', 'bit', 'tight',
#         'go', 'normal', 'probably', 'use', 'shirt', 'travel', 'every',
#         'day', 'work', 'long'],
#        dtype='<U185'),
#  array(['is', 'the', 'color', 'for', 'too', 'and', 'great', 'they', 'are',
#         'wear', 'nice', 'like', 'out', 'these', 'shoes', 'really', 'daily',
#         'working'],
#        dtype='<U185'),
#  array(['it', 'just', 'about', 'when', 'the', 'more', 'not', 'to', 'over',
#         'for', 'don', 'and', 'that', 'they', 'what', 'can', 'one',
#         'underwear', 'much', 'comfortable', 'my', 'as', 'with', 'wear',
#         'even', 'out', 'you', 'wash', 'these', 'bought', 'now', 've',
#         'travel', 'really', 're', 'marketed', 'theoretically', 'take',
#         'two', 'pairs', 'easily', 'world', 'dry', 'quickly', 'once',
#         'wrung', 'excess', 'water', 'surprisingly', 'retain', 'odor',
#         'taken', 'many', 'years', '40', 'countries', 'default', 'traveling'],
#        dtype='<U185'),
#  array(['was', 'is', 'of', 'the', 'for', 'at', 'fit', 'and', 'that',
#         'quality', 'great', 'are', 'waist', 'fabric', 'an', 'these', 'work',
#         'finding', 'khaki', 'jeans', 'someone', 'who', 'has', '29', '30',
#         'inseam', 'durable', 'accepted', 'ongoing', 'challenge',
#         'impressed', 'substantial', 'workmanship'],
#        dtype='<U185'),
#  array(['it', 'just', 'is', 'the', 'not', 'to', 'for', 'too', 'and',
#         'great', 'price', 'large', 'buy', 'your', 'card', 'all', 'pockets',
#         'simple', 'practical', 'enough', 'hold', 'snug'],
#        dtype='<U185'),
#  array(['it', 'just', 'about', 'is', 'online', 'put', 'of', 'the', 'thing',
#         'more', 'to', 'up', 'for', 'don', 'too', 'big', 'also', 'length',
#         'pretty', 'will', 'try', 'on', 'back', 'fit', 'have', 'and', 'that',
#         'quality', 'great', 'ordered', 'large', 'am', '34', 'they', 'are',
#         'in', 'one', 'much', 'but', 'my', 'them', 'buy', 'been', 'waist',
#         'wear', 'think', 'll', 'even', 'were', 'only', 'or', 'an',
#         'another', 'pair', 'forever', 'so', 'these', 'hard', 'after',
#         'reading', 'reviews', 'wore', 'time', 'things', 've', 'shirt',
#         'every', 'take', 'pairs', 'once', 'many', 'jeans', 'new',
#         'favorite', 'never', 'had', 'small', 'bottom', 'extremely', 'find',
#         'pants', 'hate', 'going', 'into', 'store', 'because', 'right',
#         'medium', 'between', '11', '13', 'depending', 'brand', 'afraid',
#         'having', 'send', 'decided', 'chance', 'ever', 'course', 'tad',
#         'washed', 'dried', 'better', 'actually', 'hem', 'excited', 'buying',
#         'silver', 'case', 'me', 'gets', 'expensive', 'notice', 'difference',
#         'compared', 'paying', '20', 'vs', '120', 'same', 'got', 'times',
#         'pleased'],
#        dtype='<U185'),
#  array(['it', 'beautiful', 'not', 'up', 'love', 'quality', 'great',
#         'comfortable', 'wash', 'after', 've', 'extremely', 'ever', 'best',
#         'bra', 'purchased', 'stays', 'does', 'roll'],
#        dtype='<U185'),
#  array(['which', 'is', 'to', 'size', 'fit', 'perfectly', 'and', 'ordered',
#         'they', 'are', 'in', 'can', 'my', 'them', 'wear', 'so', 'these',
#         'cute', 'boots', 'usually', 'person', 'wait'],
#        dtype='<U185'),
#  array(['the', 'this', 'up', 'for', 'don', 'very', 'fit', 'and', 'price',
#         'they', 'are', 'in', 'comfortable', 'them', 'would', 'or', 'you',
#         'really', 'brand', 'brought', 'past', 'ride', 'cut', 'reccommend',
#         'style'],
#        dtype='<U185'),
#  array(['it', 'just', 'is', 'plus', 'when', 'of', 'the', 'thing', 'this',
#         'more', 'not', 'to', 'then', 'up', 'over', 'for', 'don', 'also',
#         'length', 'than', 'perfectly', 'love', 'have', 'that', 'shoulders',
#         '34', 'in', 'one', 'but', 'here', 'comfortable', 'my', 'buy',
#         'would', 'been', 'with', 'nice', 'only', 'or', 'out', 'warm',
#         'after', 'first', 'around', 'be', 've', 'received', 'pockets',
#         'day', 'really', 'dry', 'years', 'has', 'had', 'find', 'because',
#         'me', 'purely', 'coat', 'except', 'little', 'narrow', 'completely',
#         'uncomfortable', 'reaching', 'close', 'car', 'door', 'rest', 'fits',
#         'where', 'complaint', 'hood', 'less', 'drapes', 'head', 'without',
#         'crushing', 'hairdoo', 'sturdy', 'zipper', 'snaps', 'toggle',
#         'buttons', 'added', 'protection', 'able', 'fill', 'yet', 'queen',
#         'filling', 'perfect', 'hitting', 'mid', 'knee', 'we', 'cold',
#         'rainy', 'stayed', 'toasty', 'entire', 'trip', 'live', 'southeast',
#         'hit', 'subzero', 'weather', 'humidity', 'our', 'feels', 'kept',
#         'comfortably', 'star', 'inch', 'done'],
#        dtype='<U185'),
#  array(['it', 'just', 'of', 'the', 'color', 'this', 'for', 'don', 'love',
#         'have', 'and', 'great', 'price', 'they', 'are', 'my', 'them', 'buy',
#         'if', 'even', 'only', 'like', 'get', 'you', 'so', 'these', 'shoes',
#         'work', 'finding', 'had', 'month', 'gone', 'through', 'lots',
#         'hiking', 'yard', 'worth', '35', 'nevados', 'swear', 'heart',
#         'stopped'],
#        dtype='<U185'),
#  array(['it', 'just', 'when', 'however', 'of', 'the', 'this', 'still', 'to',
#         'from', 'for', 'on', 'fit', 'love', 'have', 'and', 'that', 'great',
#         'some', 'they', 'are', 'in', 'can', 'my', 'them', 'would', 'with',
#         'wear', 'fabric', 'get', 'out', 'you', 'your', 'so', 'these',
#         'want', 'now', 've', 'shape', 'run', 'really', 'dry', '40', 'never',
#         'because', 'right', 'me', 'bra', 'sturdy', 'perfect', 'didn',
#         'invest', 'whole', 'nursing', 'tank', 'upwards', 'although',
#         'since', 'seemed', 'built', 'bras', 'tanks', 'paired', 'cheapies',
#         'target', 'pulled', 'owned', 'year', 'minor', 'pilling', 'sun',
#         'fading', 'hung', 'outside', 'santiago'],
#        dtype='<U185'),
#  array(['is', 'of', 'the', 'this', 'to', 'very', 'and', 'need', 'quality',
#         'am', 'they', 'are', 'in', 'what', 'came', 'as', 'with', 'nice',
#         'even', 'you', 'your', 'pair', 'these', 'pleased', 'toasty',
#         'earmuffs', 'exactly', 'pictured', 'product', 'keep', 'ears', 'damp'],
#        dtype='<U185'),
#  array(['about', 'before', 'of', 'the', 'not', 'shopping', 'to', 'up',
#         'for', 'don', 'at', 'will', 'on', 'and', 'that', 'they', 'way',
#         'can', 'one', 'but', 'as', 'them', 'thigh', 'if', 'did', 'll',
#         'pair', 'wash', 'these', 'today', 'used', 'be', 'other', 'use',
#         'easily', 'dry', 'hold', 'new', 'had', 'course', 'update', '17',
#         '14', 'wearing', 'gentle', 'cycle', 'lowest', 'setting',
#         'replacement', 'needed', 'old', 'undies', 'torn', 'apart', 'leg',
#         'seam', 'inches', 'arrive', 'inspected', 'start', 'falling',
#         'expect', 'brands'],
#        dtype='<U185'),
#  array(['it', 'was', 'put', 'the', 'this', 'still', 'to', 'well', 'bad',
#         'good', 'on', 'fit', 'and', 'that', 'ordered', 'are', 'in', 'what',
#         'can', 'one', 'would', 'if', 'think', 'even', 'like', 'you', 'your',
#         'another', 'pair', 'so', 'feet', 'be', 'has', 'had', 'depending',
#         'me', 'second', 'should', 'softest', 'foot', 'pad', 'how',
#         'recommend', 'shoe', 'remove', 'insole'],
#        dtype='<U185'),
#  array(['which', 'is', 'the', 'color', 'more', 'to', 'from', 'for', 'don',
#         'than', 'shown', 'back', 'perfectly', 'love', 'have', 'and', 'that',
#         'great', 'they', 'are', 'in', 'much', 'but', 'my', 'as', 'with',
#         'even', 'last', 'so', 'these', 'any', 'comfort', 'level', 'shoes',
#         'feet', 'off', 'be', 'all', 'new', 'actually', 'me', 'got', 'cut',
#         'stable', 'balances', 'december', 'lateral', 'jumps', 'kicks',
#         'angles', 'haven', 'circulation', 'either', 'stability', 'isn',
#         'compromise', 'richer', 'brighter', 'pinker', 'bright', 'workout',
#         'make', 'smile', 'cushioning', 'seems', 'okay', 'adjusting',
#         'cushion', 'appropriate'],
#        dtype='<U185'),
#  array(['the', 'up', 'for', 'and', 'that', 'are', 'comfortable', 'with',
#         'like', 'these', 'really', 'many', 'years', 'durable', 'hold',
#         'should', 'title', 'says', 'plush', 'soles'],
#        dtype='<U185'),
#  array(['for', 'neck', 'fit', 'and', 'great', 'are', 'in', 'these',
#         'bought', 'shirts', 'use', 'medium', 'perfect', 'recommend',
#         'thely', 'everyday', 'highly'],
#        dtype='<U185'),
#  array(['it', 'about', 'which', 'was', 'is', 'put', 'of', 'the', 'this',
#         'still', 'not', 'to', 'for', 'at', 'have', 'and', 'that', 'some',
#         'in', 'much', 'but', 'comfortable', 'areas', 'as', 'them', 'if',
#         'waist', 'there', 'belt', 'you', 'could', 'so', 'after', 'off',
#         'be', 'hours', 'pockets', 'go', 'probably', 'travel', 'day', 'take',
#         'never', 'had', 'extremely', 'purchased', 'except', 'little', 'we',
#         'trip', 'our', 'inch', '14', 'needed', 'should', 'money', 'several',
#         'sites', 'agent', 'warned', 'pick', 'being', 'nuisance', 'tourist',
#         'each', 'passports', 'spare', 'emergency', 'cash', '15', 'sight',
#         'seeing', 'constantly', 'check', 'see', '42', 'far', 'extends',
#         'stretchy', 'farther', 'might', 'hindsight', 'left', 'hotel',
#         'safe', 'airport'],
#        dtype='<U185'),
#  array(['always', 'well', 'very', 'fit', 'have', 'and', 'great', 'they',
#         'are', 'comfortable', 'shoes', 'all', 'pairs', 'several', 'olio'],
#        dtype='<U185'),
#  array(['it', 'was', 'is', 'the', 'this', 'more', 'look', 'to', 'up',
#         'well', 'for', 'dress', 'at', 'fit', 'and', 'am', 'in',
#         'comfortable', 'my', 'did', 'or', 'your', 'smooth', 'wore', 'fat',
#         'bought', 'all', 'medium', 'me', 'roll', 'didn', 'wedding', 'under',
#         'offer', 'underneath', 'definitely', 'job', 'down', 'bunch',
#         'relatively', 'considering', 'item', 'meant', 'suck', 'extra',
#         'average', 'build'],
#        dtype='<U185'),
#  array(['it', 'which', 'was', 'is', 'of', 'not', 'for', 'too', 'length',
#         'longer', 'they', 'in', 'one', 'do', 'because', 'me', 'got', 'star',
#         'needed', 'short', 'come'],
#        dtype='<U185'),
#  array(['it', 'due', 'is', 'this', 'look', 'to', 'for', 'fit', 'and',
#         'great', 'in', 'my', 'buy', 'its', 'husband', 'years', 'has', 'new',
#         'knee', 'shoe', 'staple', 'wardrobe', 'walking', 'he', 'problems',
#         'worn', 'balance'],
#        dtype='<U185'),
#  array(['not', 'to', 'don', 'at', 'least', 'too', 'no', 'fit', 'and',
#         'great', 'they', 'but', 'with', 'or', 'pair', 'last', 'forever',
#         'so', 'these', 've', 'small', 'times', 'expect', 'far', 'problems',
#         'worn', 'tall', 'saggy'],
#        dtype='<U185'),
#  array(['it', 'is', 'of', 'the', 'beautiful', 'look', 'to', 'size', 'for',
#         'dress', 'sweater', 'have', 'and', 'that', 'they', 'in', 'can',
#         'one', 'my', 'them', 'if', 'with', 'or', 'another', 'pair', 'so',
#         'these', 'want', 'be', 'other', 'tight', 'work', 'jeans', 'simple',
#         'small', 'close', 'star', 'keep', 'wearing', 'should', 'hindsight',
#         'gold', 'hoops', 'makes', 'most', 'versatile', 'earrings', 'own',
#         'casual', 'elegant', 'low', 'key', 'statement', 'necklace',
#         'requiring', 'jewelry', 'minimal', 'problem', 'resulting', 'loss',
#         'clasps', 'difficult', 'open', 'earring', 'returned'],
#        dtype='<U185'),
#  array(['it', 'is', 'of', 'the', 'for', 'on', 'perfectly', 'great',
#         'colors', 'kind', 'smooth', 'time', 'ring', 'used', 'really',
#         'right', 'fits', 'she', 'loves', 'her', 'finger', 'touch', 'sides',
#         'band', 'thick', 'deceiving', 'pic', 'by', 'amazon', 'wow', 'pop',
#         'spring', 'summer'],
#        dtype='<U185'),
#  array(['it', 'is', 'when', 'put', 'this', 'to', 'up', 'for', 'dress', 'on',
#         'and', '34', 'in', 'my', 'who', 'got', 'little', 'car', 'perfect',
#         'keep', 'he', 'fiance', 'piano', 'player', 'him', 'his', 'whenever',
#         'needs', 'plays', 'somewhere'],
#        dtype='<U185'),
#  array(['about', 'is', 'of', 'the', 'noticed', 'this', 'more', 'still',
#         'look', 'not', 'common', 'to', 'well', 'don', 'very', 'too', 'big',
#         'also', 'longer', 'than', 'stitching', 'soft', 'on', 'back', 'and',
#         'that', 'quality', 'some', 'are', 'in', 'what', 'can', 'one', 'but',
#         'comfortable', 'as', 'if', 'with', 'wear', 'were', 'belt', 'you',
#         'your', 'almost', 'these', 'feet', 'especially', 'reviews', 'wide',
#         'elastic', 'off', 'be', 've', 'other', 'smaller', 'probably',
#         'travel', 're', 'easily', 'excess', 'countries', 'enough', 'hold',
#         'find', 'going', 'better', 'me', 'cut', 'little', 'less', 'zipper',
#         'since', 'needed', 'brands', 'money', 'passports', 'cash', 'most',
#         'touch', 'overseas', 'developing', 'belts', 'handy', 'carrying',
#         'passport', 'lot', 'amount', 'credit', 'cards', 'atms',
#         'traditionally', 'airplane', 'tickets', 'paper', 'rare', 'days',
#         'getting', 'plenty', 'cheaper', 'construction', 'lower', 'looks',
#         'uneven', 'regular', 'nylon', 'instead', 'against', 'skin',
#         'products', 'deal', 'scissors', 'complaining', 'clasp', 'those',
#         'noticeably', 'worse', 'seen'],
#        dtype='<U185'),
#  array(['it', 'just', 'about', 'was', 'is', 'when', 'of', 'the', 'thing',
#         'this', 'more', 'still', 'look', 'not', 'to', 'then', 'up', 'over',
#         'for', 'don', 'very', 'than', 'no', 'good', 'feel', 'will', 'try',
#         'on', 'post', 'back', 'love', 'have', 'and', 'that', 'great', 'am',
#         '34', 'some', 'room', 'they', 'in', 'what', 'one', 'underwear',
#         'much', 'but', 'my', 'mine', 'came', 'as', 'advertised', 'would',
#         'been', 'with', 'matter', 'even', 'there', 'like', 'get', 'out',
#         'wash', 'so', 'hard', 'especially', 'man', 'after', 'time', 'worry',
#         'do', 'elastic', 'off', 'used', 'be', 'weight', 'took', 'go',
#         'probably', 'shirt', 'day', 're', 'dry', 'once', 'water', 'who',
#         'has', 'never', 'bottom', 'find', 'into', 'better', 'me', 'gets',
#         'ride', 'cold', 'kept', 'star', 'through', 'lots', 'wearing',
#         'start', 'how', 'recommend', 'okay', 'job', 'down', 'loves', 'lot',
#         'skin', 'deal', 'skinny', 'guy', 'loose', 'addition', '50lbs',
#         'horribly', 'self', 'conscious', 'boobs', 'nipples', 'poking',
#         'though', 'longest', 'gf', 'suggesting', 'hide', 'started',
#         'undershirt', 'across', 'gynecomastia', 'thought', 'looking',
#         'others', 'harder', 'let', 'air', 'prevent', 'shrinkage', 'week',
#         'stairs', 'bounce', 'showing', 'given', 'rating', 'drives', 'nuts',
#         'riding', 'sit', 'bend', 'polo', 'tucked', 'rides', 'caught',
#         'handles', 'point', 'hurts', 'myself', 'frequently', 'throughout',
#         'slipping', 'bath', 'pull', 'tuck', 'tried', 'safety', 'pins',
#         'bends', 'severely', 'eventually', 'lol', 'line', 'works',
#         'stomach', 'anyone'],
#        dtype='<U185'),
#  array(['it', 'just', 'which', 'is', 'the', 'color', 'this', 'more', 'not',
#         'to', 'for', 'than', 'good', 'and', 'in', 'one', 'much', 'but',
#         'my', 'as', 'with', 'think', 'its', 'you', 'an', 'black', 'bit',
#         'actually', 'got', 'person', 'except', 'perfect', 'might', 'open',
#         'deceiving', 'looks', 'looking', 'daughter', 'described', 'photo',
#         'ivory', 'darker', 'beige', 'nicer', 'know', 'continuous', 'piece',
#         'scarf', 'knew', 'prior', 'purchase'],
#        dtype='<U185'),
#  array(['it', 'when', 'ordering', 'of', 'the', 'not', 'to', 'size', 'for',
#         'at', 'very', 'too', 'return', 'and', 'way', 'can', 'much', 'but',
#         'my', 'as', 'them', 'did', 'or', 'like', 'you', 'another', 'pair',
#         'made', 'all', 'true', 'order', 'work', 'really', 'someone', 'had',
#         'small', 'me', 'best', 'he', 'lot', 'son', 'slippers', 'poor',
#         'sizing', 'guess', 'hope', 'give', 'gift', 'else'],
#        dtype='<U185'),
#  array(['it', 'just', 'which', 'was', 'why', 'is', 'when', 'put', 'of',
#         'the', 'this', 'beautiful', 'look', 'not', 'to', 'then', 'size',
#         'up', 'well', 'for', 'don', 'very', 'too', 'than', 'no', 'good',
#         'feel', 'will', 'on', 'back', 'fit', 'perfectly', 'love', 'have',
#         'and', 'that', 'ordered', 'some', 'they', 'are', 'in', 'way', 'can',
#         'one', 'say', 'but', 'here', 'my', 'as', 'them', 'if', 'with',
#         'were', 'only', 'or', 'like', 'you', 'could', 'pair', 'so', 'feet',
#         'after', 'comfy', 'do', 'around', 'black', 'be', 'bought', 'all',
#         'now', 'arch', 'support', 'took', 'bit', 're', 'take', 'easily',
#         'quickly', 'many', 'years', 'who', '30', 'right', 'send', 'better',
#         'got', 'little', 'toasty', 'month', 'worth', 'second', 'should',
#         'foot', 'insole', 'soles', '15', 'under', 'down', 'extra',
#         'looking', 'slipping', 'tweaking', 'insoles', 'became', 'rich',
#         'deep', 'waterproofed', 'sofsole', 'people', 'toes', 'scrunched',
#         'front', 'ten', 'minutes', 'began', 'hurt', 'paid', 'erg',
#         'finally', 'actual', 'fine', 'add', 'already', 'loosened', 'wee',
#         'sure', 'stretch', 'fleece', 'packing', 'pros', 'sweaty', 'stinky',
#         'seem', 'softer', 'ugg', 'ultimates', 'outer', 'flexible', 'role',
#         'walk', 'ergonomically', 'tip', 'toe', 'floor', 'apt', 'tweaks',
#         'cons', 'slide', 'potentially', 'cause', 'hot', 'spots', 'sloppy',
#         'tender', 'may', 'spite', 'their', 'boasting', 'inserts', 'care',
#         'living', 'uggs', 'emu', 'cushy', 'uggers', '00', 'website',
#         'slipped', 'aah', 'slip', 'dollars', 'later', 'hey', 'pamper',
#         'tread', 'shallow', 'cake', 'snow', 'making', 'slippery', 'unless',
#         'agile', 'ice', 'break', 'hazard'],
#        dtype='<U185'),
#  array(['it', 'about', 'was', 'of', 'the', 'this', 'not', 'to', 'for',
#         'very', 'too', 'good', 'loved', 'fit', 'and', 'price', 'ordered',
#         'large', 'wanted', 'what', 'but', 'my', 'with', 'nice',
#         'description', 'bought', 'small', 'because', 'mid', 'seemed', 'she',
#         'looks', 'handles', 'daughter', 'sure', 'christmas', 'bag',
#         'somewhat', 'tote', 'material'],
#        dtype='<U185'),
#  array(['was', 'the', 'this', 'not', 'well', 'don', 'at', 'very', 'will',
#         'on', 'return', 'have', 'that', 'much', 'description', 'or', 'all',
#         'enough', 'because', 'bra', 'does', 'didn', 'either', 'give',
#         'slip', 'padding', 'maybe', 'read', 'focused', 'straps', 'away'],
#        dtype='<U185'),
#  array(['about', 'of', 'the', 'not', 'very', 'have', 'am', 'some', 'they',
#         'are', 'much', 'comfortable', 'as', 'if', 'waist', 'like', 'these',
#         'other', 'pants', 'band', 'though', 'sure', 'scrub', 'cherokee',
#         'crazy', 'otherwise'],
#        dtype='<U185'),
#  array(['it', 'why', 'is', 'when', 'put', 'of', 'the', 'this', 'not', 'to',
#         'then', 'up', 'from', 'over', 'for', 'don', 'very', 'on', 'have',
#         'and', 'that', 'some', 'in', 'can', 'one', 'but', 'comfortable',
#         'my', 'light', 'cool', 'if', 'been', 'with', 'think', 'fabric',
#         'even', 'there', 'or', 'like', 'out', 'you', 'trying', 'your', 'so',
#         'around', 'off', 'used', 'heavy', 'shirt', 'long', 'easily', 'many',
#         'who', 'has', 'durable', 'enough', 'ever', 'better', 'gets', 'same',
#         'does', 'usually', 'style', 'car', 'fits', 'perfect', 'live',
#         'weather', 'gone', 'keep', 'circulation', 'make', 'under',
#         'walking', 'worn', 'by', 'spring', 'carrying', 'days', 'nylon',
#         'air', 'anyone', 'know', 'people', 'sweaty', 'their', 'jacket',
#         'northwest', 'rarely', 'below', '100', 'degrees', 'canvas', 'shell',
#         'dickies', 'known', 'quilted', 'lining', 'non', 'removeable',
#         'carhartt', 'flannel', 'important', 'sleeve', 'grab', 'caising',
#         'friend', 'types', 'jackets', 'linings', 'push', 'taking', 'coats',
#         'sweat', 'wind', 'breakers', 'breathe', 'freezing', 'town', 'bill',
#         'commuters', 'modern', 'fully', 'closed', 'won', 'catch', 'blunt',
#         'sharp', 'objects', 'polyester', 'act', 'spaghetti', 'warms',
#         'circus', 'sliding', 'arm', 'walks', 'held', 'collar', 'shoved',
#         'traveller', 'commuter', 'fall', 'winter', 'bus', 'train', 'rail'],
#        dtype='<U185'),
#  array(['it', 'just', 'is', 'of', 'the', 'color', 'more', 'to', 'size',
#         'for', 'very', 'than', 'no', 'good', 'fit', 'and', 'that', 'great',
#         'are', 'in', 'one', 'my', 'seams', 'if', 'with', 'll', 'were',
#         'get', 'out', 'these', 'shoes', 'feet', 'true', 'took', 'long',
#         'enough', 'right', 'me', 'except', 'sturdy', 'hiking', 'needed',
#         'seam', 'foot', 'make', 'summer', 'against', 'across', 'toe',
#         'care', 'tread', 'sensitive', 'inside', 'rubs', 'blister', 'place',
#         'sandals', 'box', 'breaking', 'covered', 'moleskin', 'velcro',
#         'adjustments', 'instep', 'heel', 'allow', 'smokey', 'brown', 'gray'],
#        dtype='<U185'),
#  array(['the', 'to', 'very', 'too', 'longer', 'than', 'will', 'on', 'have',
#         'and', 'quality', 'great', 'they', 'are', 'what', 'one',
#         'comfortable', 'my', 'been', 'with', 'think', 'socks', 'last',
#         'these', 'where', 'we', 'year', 'old', 'says', 'extra', 'he', 'lot',
#         'getting', 'seem', 'reinforcements', 'sole', 'holes', 'appear',
#         'active', 'picky'],
#        dtype='<U185'),
#  array(['not', 'expected', 'for', 'than', 'as', 'walking', 'sole',
#         'stiffer', 'coushioned'],
#        dtype='<U185'),
#  array(['was', 'is', 'this', 'to', 'size', 'length', 'fit', 'and', 'they',
#         'in', 'were', 'pair', 'these', 'first', 'leggings', 'received',
#         'order', 'pairs', 'able', 'perfect', 'recommend', 'highly',
#         'finally', 'waited', 'until', 'jean', 'stock'],
#        dtype='<U185'),
#  array(['it', 'was', 'is', 'the', 'size', 'up', 'for', 'too', 'pretty',
#         'feel', 'perfectly', 'ordered', 'are', 'in', 'can', 'one', 'my',
#         'colors', 'as', 'with', 'nice', 'there', 'so', 'these', 'shoes',
#         'feet', 'first', 'high', 'be', 'bought', 'shape', 'arch', 'support',
#         'really', 'difference', 'got', 'fits', 'cushioning', 'considering',
#         'amazon', 'looks', 'those', 'people', 'may', 'among', 'few',
#         'listed', 'per', 'previous', 'experiences', 'asics', 'half'],
#        dtype='<U185'),
#  array(['just', 'about', 'was', 'before', 'due', 'ordering', 'of', 'to',
#         'size', 'than', 'will', 'on', 'fit', 'have', 'and', 'ordered',
#         'large', 'they', 'in', 'way', 'my', 'them', 'were', 'like',
#         'another', 'pair', 'so', 'these', 'any', 'first', 'black', 'be',
#         'all', 'received', 'pants', 'because', 'better', 'got', 'less',
#         'arrive', 'short', 'own', 'summer', 'week', 'tried', 'read',
#         'jeggings', 'initially', 'discouraged', 'looked', 'remembered',
#         'review', 'appearing', 'anyway', 'ladies', 'damn', 'dream',
#         'hugged', 'complimented', '170lb', 'figure', 'teal'],
#        dtype='<U185'),
#  array(['the', 'more', 'to', 'than', 'on', 'love', 'and', '34', 'are', 'in',
#         'comfortable', 'my', 'them', 'buy', 'again', 'would', 'been',
#         'wear', 'nice', 'these', 'shoes', 'really', 'has', 'me', 'summer',
#         'looking', 'wife', 'adult', 'rather', 'flip', 'flops'],
#        dtype='<U185'),
#  array(['it', 'is', 'this', 'to', 'from', 'over', 'have', 'and', 'that',
#         'great', 'some', 'my', 'as', 'belt', 'an', 'comfort', 'things',
#         'really', 'had', 'pants', 'able', 'yet', 'needed', 'being', 'down',
#         'give', 'sliding', '60', 'shifted', 'body', 'wise', 'keeping',
#         'effort', 'tighten'],
#        dtype='<U185'),
#  array(['which', 'was', 'is', 'look', 'to', 'don', 'bad', 'very', 'good',
#         'on', 'and', 'that', 'they', 'are', 'in', 'my', 'light', 'them',
#         'nice', 'out', 'an', 'your', 'these', 'all', 'weight', 'day',
#         'take', 'easily', 'had', 'ears', 'come', 'pull', 'finally',
#         'earings', 'losing', 'earing', 'yesterday', 'purse'],
#        dtype='<U185'),
#  array(['to', 'for', 'will', 'love', 'and', 'they', 'in', 'my', 'them',
#         'cute', 'be', 'day', 're', 'going', 'hit', 'gift', 'irish', 'men',
#         'st', 'patrick', 'parade'],
#        dtype='<U185'),
#  array(['it', 'just', 'about', 'is', 'the', 'this', 'not', 'to', 'then',
#         'for', 'feel', 'fit', 'perfectly', 'have', 'and', 'that', 'great',
#         'ordered', 'am', 'are', 'but', 'goes', 'my', 'buy', 'kind', 'if',
#         'with', 'design', 'even', 'there', 'or', 'like', 'lbs', 'its',
#         'out', 'you', 'so', 'want', 'made', 'all', 'shirts', 'other', 'go',
#         'shirt', 'long', 'really', 'small', 'find', 'brand', 'me', 'times',
#         'does', 'fits', 'since', 'should', 'casual', 'sleeve', 'figure',
#         'body', 'reference', '140', 'us', 'mean', 'slim', 'nicely', 'wont',
#         'debating', 'stop', 'thinking', '25', 'beats', 'name', 'cost',
#         'twice', 'three', 'cloth', 'thin', 'cheaply', 'indeed'],
#        dtype='<U185'),
#  array(['just', 'of', 'the', 'look', 'for', 'don', 'than', 'good', 'love',
#         'have', 'and', 'great', 'they', 'in', 'can', 'colors', 'them',
#         'wear', 'even', 'were', 'get', 'out', 'you', 'these', 'any',
#         'comfort', 'shoes', 'off', 'all', 'now', 'better', 'purchased',
#         'without', 'come', 'thought', 'taking', 'heel', 'until', '60',
#         'multiple', 'fabrics', 'turned', 'heels', 'flat', 'hour', 'dance',
#         'night'],
#        dtype='<U185'),
#  array(['just', 'is', 'put', 'of', 'the', 'this', 'beautiful', 'will', 'on',
#         'have', 'one', 'out', 'your', 'ever', 'worn', 'skin', 'seen',
#         'prettiest', 'pendants', 'sparkle', 'eyes'],
#        dtype='<U185'),
#  array(['is', 'the', 'to', 'different', 'very', 'too', 'longer', 'love',
#         'and', 'comfortable', 'them', 'these', 'has', 'because', 'style',
#         'little', 'leg'],
#        dtype='<U185'),
#  array(['the', 'at', 'very', 'and', 'am', 'are', 'in', 'comfortable', 'my',
#         'wear', 'out', 'socks', 'so', 'these', 'feet', 'time', 'happy',
#         'brands', 'short', 'cheaper', 'heel', 'strong'],
#        dtype='<U185'),
#  array(['it', 'just', 'is', 'the', 'picture', 'this', 'not', 'up', 'for',
#         'than', 'soft', 'on', 'love', 'and', 'in', 'one', 'itchy', 'if',
#         'out', 'you', 'made', 'reading', 'comfy', 'took', 'shirt', 're',
#         'because', 'me', 'star', 'wearing', 'recommend', 'thick', 'by',
#         'loose', 'looking', 'material', 'away', 'turned', 'curled', 'fire',
#         'book', 'slightly', 'baggier', '130lbs', 'something', 'cozy',
#         'relaxing'],
#        dtype='<U185'),
#  array(['it', 'was', 'the', 'this', 'not', 'to', 'size', 'well', 'dress',
#         'very', 'fit', 'love', 'and', 'are', 'but', 'comfortable', 'colors',
#         'would', 'fabric', 'true', 'really', 'right', 'afraid', 'me',
#         'making', 'brilliant', 'moves', 'breathes', 'sexy'],
#        dtype='<U185'),
#  array(['is', 'the', 'look', 'size', 'well', 'than', 'fit', 'have', 'and',
#         'they', 'are', 'but', 'comfortable', 'as', 'would', 'wear', 'like',
#         'these', 'bought', 'really', 'better', 'me', 'usually', 'exactly',
#         'definitely', 'photo'],
#        dtype='<U185'),
#  array(['not', 'to', 'size', 'well', 'ordered', 'they', 'but', 'my', 'them',
#         'were', 'get', 'could', 'so', 'made', 'normal', 'friend', 'zipped',
#         'gave'],
#        dtype='<U185'),
#  array(['it', 'is', 'the', 'color', 'this', 'not', 'for', 'too', 'than',
#         'will', 'and', 'great', 'cool', 'with', 'fabric', 'you', 'so',
#         'bit', 'tight', 'go', 'bra', 'fits', 'through', 'tank', 'keep',
#         'see', 'spring', 'summer', 'loose', 'though', 'ivory', 'sizing',
#         'thin', 'dressier', 'top', 'correct', 'flattering', 'everything',
#         'mind'],
#        dtype='<U185'),
#  array(['it', 'which', 'was', 'of', 'the', 'this', 'to', 'from', 'for',
#         'at', 'least', 'length', 'good', 'on', 'arms', 'have', 'and',
#         'large', '34', 'in', 'way', 'but', 'if', 'nice', 'even', 'like',
#         'lbs', 'you', 'want', 'hard', 'after', 'high', 'black', 'shape',
#         'order', 'unfortunately', 'long', 'retain', 'has', 'enough', '11',
#         'dried', 'me', 'person', 'keep', 'stretchy', 'makes', 'him', 'away',
#         'arm', 'figure', 'sexy', 'top', 'everything', 'fabulous', 'blue',
#         'limby', '160', 'tempted', 'xl', 'quite', 'ample', 'despite',
#         'hugging', 'curves', 'word', 'caution', 'dryer', 'learned',
#         'boyfriend', 'max', 'shrieked', 'moved', 'reluctant', 'acceptance',
#         'phase', 'pajama'],
#        dtype='<U185'),
#  array(['it', 'just', 'was', 'is', 'the', 'still', 'not', 'don', 'very',
#         'great', 'price', 'but', 'comfortable', 'my', 'would', 'like', 'be',
#         'took', 'because', 'bra', 'fits', 'recommend', 'definitely', 'by',
#         'top', 'chances', 'within', 'reason', 'fooled', 'itself', 'fittedv'],
#        dtype='<U185'),
#  array(['of', 'the', 'still', 'to', 'for', 'no', 'will', 'fit', 'have',
#         'and', 'that', 'they', 'are', 'in', 'what', 'but', 'my', 'them',
#         'kind', 'wear', 'nice', 'matter', 'only', 'like', 'socks', 'these',
#         'comfy', 'husband', 'do', 'around', 'bought', 'shirts', 'really',
#         'weather', 'year', 'cushion', 'he', 'loves', 'summer', 'cause',
#         'nicely', 'cooler', 'ankle', 'hanes', 'boxers', 'tee'],
#        dtype='<U185'),
#  array(['up', 'bra', 'beige', 'push', 'body', 'sexy', 'maidenform', 'women',
#         'feeling', 'ultimate', 'gel', '34amuy', 'buen', 'producto', 'en',
#         'calidad', 'costo', 'recomendado', 'por', 'bajo', 'tipo', 'de',
#         'embalage', 'el', 'envio', 'tiempo', 'entrega', 'excelente',
#         'recomendao', 'para', 'uso', 'diario', 'comodidad', 'inclusive'],
#        dtype='<U185'),
#  array(['of', 'the', 'color', 'not', 'to', 'up', 'for', 'and', 'that',
#         'great', 'they', 'are', 'with', 'were', 'get', 'could', 'pair',
#         'these', 'shoes', 'made', 'laces', 'be', 'hold', 'new', 'right',
#         'got', 'without', 'done', 'job', '45', 'six', 'eyelet', 'somebody',
#         'sneakers', 'stunted', 'stiff', 'tie', 'significant'],
#        dtype='<U185'),
#  array(['about', 'ago', 'was', 'is', 'of', 'the', 'to', 'from', 'well',
#         'for', 'don', 'at', 'big', 'good', 'on', 'and', '34', 'they', 'are',
#         'but', 'my', 'them', 'buy', 'wear', 'fabric', 'were', 'another',
#         'pair', 'these', 'after', 'first', 'be', 'bought', 'all', 've',
#         'use', 'work', 'daily', 'between', '13', 'me', 'little', 'seemed',
#         '14', 'wearing', 'needed', 'everyday', 'regular', 'started',
#         'thought', 'week', 'point', 'seem', 'inside', 'box', 'until', 'few',
#         'three', 'mind', 'boxers', 'six', 'pack', 'retailer', 'months',
#         'both', 'running', 'roughly', 'miles', 'weeks', 'machine',
#         'washing', 'drying', 'slowly', 'surely', 'ball', 'balling', 'legs',
#         'supposed', 'performance', 'boxer', 'briefs', 'perform', 'chaffing',
#         'discomfort', 'please', 'avoid', 'exercise'],
#        dtype='<U185'),
#  array(['it', 'is', 'the', 'this', 'to', 'different', 'don', 'very', 'will',
#         'have', 'they', 'are', 'in', 'way', 'can', 'but', 'buy', 'would',
#         'with', 'think', 'fabric', 'even', 'or', 'impossible', 'socks',
#         'hard', 'first', 'time', 'be', 'all', 'use', 'shirt', 'easily',
#         'enough', 'stays', 'since', 'make', 'thick', 'harder', 'itself',
#         'clip', 'attach', 'thicker', 'besides', 'detach', 'rubber', 'next',
#         'attachments'],
#        dtype='<U185'),
#  array(['it', 'arrived', 'was', 'of', 'the', 'for', 'and', 'quality',
#         'great', 'price', 'some', 'in', 'buy', 'with', 'so', 'especially',
#         'cute', 'many', 'definitely', 'went', 'outfits', 'timing'],
#        dtype='<U185'),
#  array(['was', 'is', 'however', 'of', 'the', 'more', 'not', 'to', 'up',
#         'over', 'well', 'for', 'very', 'on', 'and', 'great', 'am', 'they',
#         'in', 'can', 'much', 'my', 'light', 'them', 'been', 'with', 'were',
#         'could', 'these', 'shoes', 'first', 'be', 've', 'run', 'enough',
#         'me', 'done', 'wearing', 'stable', '15', 'down', 'minimal', 'loss',
#         'sloppy', 'quite', 'running', 'next', 'trails', 'while',
#         'technical', 'ankles', 'vibram', 'outsoles', 'grip', 'rockier',
#         'slicker', 'conditions', 'speedcross', 'cs', 'solution', 'grippy',
#         'aggressive', 'rocky', 'boulders', 'hill', 'sections', 'mile',
#         'trail', '2700', 'ft', 'elevation', 'gain', 'felt', 'ready', 'ramp',
#         '50k'],
#        dtype='<U185'),
#  array(['the', 'to', 'different', 'for', 'have', 'and', 'price', 'they',
#         'are', 'can', 'get', 'you', 'these', 'all', 'because', 'we',
#         'jewelry', 'started', 'gift', 'family', 'friends', 'such', 'fun',
#         'novelty', 'beat', 'experience'],
#        dtype='<U185'),
#  array(['was', 'is', 'the', 'to', 'over', 'well', 'for', 'on', 'fit',
#         'perfectly', 'and', 'in', 'my', 'were', 'hard', 'made', 'hold',
#         'case', 'sturdy', 'amazon', 'looking', 'listed', 'sunglasses',
#         'appears', 'dimensions', 'spot'],
#        dtype='<U185'),
#  array(['it', 'was', 'this', 'well', 'for', 'loved', 'and', 'need', 'one',
#         'if', 'with', 'get', 'you', 'made', 'cute', 'someone', 'she',
#         'gift', 'obsessed', 'pink'],
#        dtype='<U185'),
#  array(['it', 'arrived', 'was', 'before', 'of', 'the', 'still', 'up',
#         'than', 'fit', 'love', 'and', 'that', 'ordered', '34', 'what',
#         'with', 'nice', 'were', 'almost', 'took', 'other', 'bit', 'long',
#         'two', 'easily', 'pants', 'because', 'right', 'medium', 'without',
#         'short', 'care', 'sleeves', 'butt', 'covering', 'wearable', 'uh',
#         'matters', 'graphic', 'freshly', 'printed', 'smell', 'stiffness',
#         'washes'],
#        dtype='<U185'),
#  array(['it', 'just', 'the', 'this', 'to', 'on', 'have', 'and', 'am', 'but',
#         'as', 'enjoying', 'would', 'with', 'or', 'an', 'another', 'reviews',
#         'today', 'now', 'advice', 'other', 'shirt', 'work', 'right',
#         'decided', 'better', 'wearing', 'far', 'under', 'undershirt',
#         'sizing', 'sweat', 'hoodies', 'warmth', 'heavier', 'thanks'],
#        dtype='<U185'),
#  array(['it', 'the', 'for', 'big', 'will', 'love', 'they', 'but', 'as',
#         'watch', 'things', 'bit', 'wee', 'hello', 'kitty', 'girls',
#         'mentioned'],
#        dtype='<U185'),
#  array(['beautiful', 'and', 'large', 'they', 'are', 'but', 'comfortable',
#         'them', 'even', 'you', 'do', 'run', 'me', 'make', 'see', 'tall',
#         'gorgeous', 'barely'],
#        dtype='<U185'),
#  array(['is', 'of', 'the', 'this', 'different', 'for', 'and', 'that', 'one',
#         'my', 'with', 'only', 'card', 'bought', 'all', 'other', 'brand',
#         'we', 'our', 'worth', 'brands', 'extra', 'credit', 'dollars', 'few',
#         'holders', 'college', 'age', 'kids', 'hasn', 'broken', 'replaced',
#         'ones'],
#        dtype='<U185'),
#  array(['it', 'was', 'is', 'the', 'picture', 'this', 'to', 'size', 'up',
#         'well', 'for', 'don', 'very', 'too', 'also', 'no', 'good', 'feel',
#         'have', 'and', 'that', 'in', 'way', 'one', 'much', 'but', 'buy',
#         'did', 'wear', 'there', 'want', 'do', 'liked', 'support', 'bottom',
#         'hate', 'bra', 'didn', 'bras', 'should', 'sides', 'band', 'looks',
#         'looking', 'material', 'thin', 'something', 'correct', 'girls',
#         'write', 'wire', 'absolutely', 'stay', 'cup', 'area', 'yes',
#         'firmer', 'rolled', 'flimsy'],
#        dtype='<U185'),
#  array(['the', 'this', 'for', 'very', 'fit', 'and', '34', 'comfortable',
#         'my', 'light', 'like', 'weight', 'use', 'durable', 'shoe', 'riding',
#         'boot', 'mostly', 'motorcycle'],
#        dtype='<U185'),
#  array(['it', 'is', 'of', 'the', 'color', 'picture', 'this', 'more',
#         'beautiful', 'not', 'to', 'for', 'shown', 'in', 'my', 'as', 'like',
#         'an', 'so', 'off', 'go', 'many', 'has', 'does', 'star', 'though',
#         'scarf', '100', 'outfits', 'cashmere', 'knocked', 'false',
#         'advertising', 'label', 'states', 'wool', 'itch', 'white', 'ecru',
#         'become', 'matches'],
#        dtype='<U185'),
#  array(['is', 'of', 'the', 'this', 'to', 'different', 'up', 'well', 'very',
#         'will', 'have', 'and', 'that', 'in', 'one', 'comfortable', 'my',
#         'as', 'would', 'if', 'could', 'pair', 'last', 'these', 'shoes',
#         'time', 'all', 'day', 'new', 'ever', 'same', 'style', 'second',
#         'several', 'worn', 'most', 'walk', 'held', 'previous', 'styles',
#         'deer', 'stags', 'rate', 'includes', 'althetic', 'tell', 'standards'],
#        dtype='<U185'),
#  array(['it', 'was', 'the', 'this', 'more', 'to', 'for', 'very', 'on',
#         'have', 'and', 'need', 'in', 'can', 'one', 'my', 'colors', 'you',
#         'your', 'lovely', 'now', 'order', 'other', 'take', 'two', 'small',
#         'find', 'pleased', 'does', 'item', 'bag', 'few', 'while', 'cup',
#         'silk', 'special', 'occasions', 'barest', 'essentials', 'wrist',
#         'hands', 'carry', 'plate', 'plan', 'receive', 'suggest', 'early'],
#        dtype='<U185'),
#  array(['it', 'just', 'is', 'when', 'of', 'the', 'color', 'not',
#         'different', 'from', 'very', 'too', 'big', 'pretty', 'will', 'on',
#         'have', 'and', 'light', 'buy', 'again', 'nice', 'even', 'or',
#         'like', 'alot', 'ring', 'quickly', 'has', 'small', 'does', 'hit',
#         'sun', 'definitely', 'looks', 'sparkle', 'hasn', 'set', 'real',
#         'diamond', 'gotten', 'compliments', 'dulled', 'tarnished', 'cane',
#         'wraped', 'secure', 'fashion', 'plaza'],
#        dtype='<U185'),
#  array(['it', 'just', 'was', 'super', 'is', 'always', 'of', 'the', 'this',
#         'more', 'to', 'different', 'up', 'from', 'for', 'dress', 'idea',
#         'will', 'love', 'have', 'and', 'great', 'company', 'am', 'can',
#         'much', 'my', 'as', 'them', 'again', 'waist', 'with', 'or', 'get',
#         'another', 'so', 'any', 'time', 'do', 'used', 'happy', 'has',
#         'better', 'item', 'extra', 'give', 'may', 'care', 'losing', 'cost',
#         'sexy', 'clothing', 'shoots', 'talent', 'enjoyment', 'playing',
#         'goth', 'adding', 'hint', 'visual', 'punch', 'cinching', 'curve',
#         'plain', 'embellish', 'shiny', 'items', 'fo', 'effecti', 'shipping',
#         'quick', 'transactiona', 'business', 'soonduane'],
#        dtype='<U185'),
#  array(['it', 'about', 'is', 'of', 'the', 'to', 'bad', 'in', 'what', 'can',
#         'say', 'much', 'fabric', 'you', 'be', 'shape', 'how', 'piece',
#         'supposed', 'special', 'cylinder', 'nothing'],
#        dtype='<U185'),
#  array(['it', 'red', 'this', 'size', 'love', 'and', 'that', 'ordered',
#         'they', 'in', 'one', 'much', 'as', 'bigger', 'get', 'you', 'so',
#         'service', 'do', 'be', 'run', 'shirt', 'small', 'hate', 'highly',
#         'though', 'won', 'disappointed', 'promise', 'recommended',
#         'excellent', 'customer', 'thank'],
#        dtype='<U185'),
#  array(['it', 'not', 'size', 'for', 'price', 'in', 'but', 'my', 'came',
#         'nice', 'like', 'bought', 'silver', 'mom', 'bronze', 'ok'],
#        dtype='<U185'),
#  array(['it', 'was', 'before', 'is', 'always', 'the', 'this', 'more',
#         'beautiful', 'to', 'for', 'than', 'pretty', 'no', 'will', 'loved',
#         'have', 'and', 'that', 'great', 'can', 'but', 'my', 'mine', 'as',
#         'matter', 'said', 'even', 'there', 'only', 'or', 'out', 'you', 'an',
#         'any', 'hard', 'after', 'reviews', 'liked', 'because', 'purchased',
#         'little', 'complaint', 'live', 'should', 'make', 'makes',
#         'necklace', 'she', 'her', 'thought', 'daughter', 'gift', 'making',
#         'christmas', 'read', 'anyway', 'rather', 'something', 'gave',
#         'boyfriend', 'family', 'mostly', 'tell', 'special', 'mom',
#         'decision', 'near', 'reminder', 'distance', 'share', 'closeness',
#         'message', 'agreed', 'realized', 'inscription', 'eyesight',
#         'manufacturer', 'change', 'font', 'clear', 'mother'],
#        dtype='<U185'),
#  array(['of', 'the', 'to', 'size', 'for', 'don', 'at', 'on', 'fit',
#         'perfectly', 'love', 'and', 'great', 'they', 'are', 'comfortable',
#         'my', 'cool', 'colors', 'them', 'buy', 'been', 'wear', 'out', 'so',
#         'these', 'feet', 've', '10', 'work', 'right', 'me', 'boots',
#         'wearing', 'inside', 'box', 'night', 'unbelievably', 'shifts',
#         'kill', 'end', 'ability', 'fold', 'tops', 'reveal', 'plaid'],
#        dtype='<U185'),
#  array(['it', 'just', 'was', 'is', 'when', 'of', 'the', 'color', 'this',
#         'shade', 'not', 'to', 'size', 'well', 'for', 'very', 'also', 'on',
#         'fit', 'have', 'and', 'ordered', 'they', 'in', 'but', 'my', 'as',
#         'them', 'would', 'wear', 'nice', 'said', 'like', 'these', 'any',
#         'made', 'today', 'around', 'be', '10', 'happy', 'other', 'travel',
#         're', 'small', 'into', 'because', '11', 'me', 'got', 'fits',
#         'perfect', 'didn', 'since', 'foot', 'being', 'might', 'hotel',
#         'definitely', 'walking', 'gold', 'thick', 'lot', 'getting',
#         'thought', 'looking', 'fine', 'sole', 'flip', 'flops', 'thin', 'xl',
#         'decision', 'change', 'foldable', 'satisfied', 'side', 'gaudy',
#         'dirty', 'streets', 'nyc', 'fairly', 'hallways', 'lobbies',
#         'airports', 'etc', 'pedicure'],
#        dtype='<U185'),
#  array(['it', 'just', 'is', 'when', 'of', 'the', 'this', 'more', 'not',
#         'idea', 'too', 'no', 'on', 'have', 'and', 'that', 'large', 'they',
#         'are', 'can', 'one', 'my', 'wish', 'would', 'if', 'or', 'stuff',
#         'could', 'an', 'any', 'around', 'bought', 'all', 'other', 'smaller',
#         'probably', 'travel', 'water', 'many', 'has', 'into', 'case',
#         'expensive', 'times', 'fits', 'since', 'keep', 'should', 'how',
#         'make', 'sides', 'against', 'though', 'making', 'held', 'inside',
#         'top', 'rubber', 'carry', 'fairly', 'waaaaaaay', 'watches', 'hobby',
#         'invictas', 'accommodate', 'sometimes', 'throw', 'luggage', 'eye',
#         'screams', 'separately', 'anything', 'injure', 'damage', 'thickly',
#         'padded', 'including', 'seal', 'securely', 'upper', 'part',
#         'resistant', 'proof', 'larger', 'holds'],
#        dtype='<U185'),
#  array(['it', 'was', 'is', 'the', 'this', 'more', 'for', 'also', 'no', 'on',
#         'and', 'great', 'as', 'like', 'bought', 'has', 'case', 'exactly',
#         'pictured', 'product', 'he', 'addition', 'gift', 'friend',
#         'watches', 'part', 'lock', 'glass', 'dresser'],
#        dtype='<U185'),
#  array(['it', 'about', 'is', 'the', 'color', 'shows', 'to', 'well', 'than',
#         'and', 'that', 'are', 'in', 'mine', 'them', 'only', 'comfy', 'took',
#         'built', 'richer', 'walking', 'photo', 'ten', 'break', 'minuts',
#         'bonus'],
#        dtype='<U185'),
#  array(['it', 'is', 'of', 'the', 'thing', 'look', 'not', 'to', 'don',
#         'stitching', 'have', 'and', 'that', 'some', 'in', 'but', 'my',
#         'only', 'like', 'its', 'get', 'so', 'cute', 've', 'does', 'hood',
#         'worn', 'makes', 'boobs', 'front', 'already', 'twice', 'ties',
# ...
#        dtype='<U185'),
#  array(['it', 'was', 'is', 'the', 'thing', 'this', 'not', 'to', 'for',
#         'very', 'good', 'and', 'are', 'in', 'my', 'if', 'with', 'even',
#         'only', 'or', 'out', 'you', 'these', 'be', 'use', 'two', 'small',
#         'going', 'because', 'better', 'little', 'able', 'gift', 'may',
#         'purse', 'mom', 'change', 'teenager', 'seconds', 'necessities',
#         'gag', 'purses', 'preteen'],
#        dtype='<U185'),
#  array(['it', 'arrived', 'which', 'was', 'the', 'this', 'to', 'at', 'too',
#         'than', 'return', 'have', 'and', 'that', 'price', 'one', 'would',
#         'get', 'another', 'off', 'weight', 'once', 'many', 'countries',
#         'right', 'me', 'able', 'amazon', 'cheaper', 'started', 'their',
#         'away', 'wise', 'itself', 'thanks', 'realized', 'throw', 'luggage',
#         'lighter', 'american', 'international', 'airlines', 'limitations',
#         'domestic', 'aping', 'pricing', 'samsonite'],
#        dtype='<U185'),
#  array(['fast', 'is', 'to', 'size', 'feel', 'on', 'fit', 'and', 'they',
#         'in', 'buy', 'if', 'with', 'like', 'get', 'you', 'your', 'another',
#         'pair', 'these', 'feet', 'happy', 'really', 'dry', 'going',
#         'correct', 'blue', 'white', 'sandal', '12', 'solid', 'dig',
#         'pillows'],
#        dtype='<U185'),
#  array(['it', 'is', 'of', 'the', 'this', 'to', 'from', 'well', 'soft', 'on',
#         'and', 'quality', 'great', 'my', 'as', 'get', 'high', 'off',
#         'outfit', 'used', 'most', 'part', 'home', 'coming', 'easy',
#         'adorable', 'importantly', 'hospital', 'photographs'],
#        dtype='<U185'),
#  array(['to', 'and', 'that', 'can', 'my', 'them', 'again', 'wear', 'like',
#         'so', 'use', 'new', 'without', 'product', 'being', 'works',
#         'finally', 'found', 'easy', 'clean', 'gems', 'embarrassed'],
#        dtype='<U185'),
#  array(['it', 'was', 'plus', 'the', 'this', 'not', 'to', 'size', 'return',
#         'fit', 'and', 'large', 'in', 'one', 'my', 'did', 'nice', 'were',
#         'like', 'shirts', 'who', 'small', 'little', 'buttons', 'product',
#         'tried', 'line', 'photo', 'friend', 'three', 'flattering', 'spot',
#         'wears', 'couldn', 'believe', 'weird', 'ran', 'asymmetrical', 'row',
#         'smalls', 'xsmall'],
#        dtype='<U185'),
#  array(['up', 'also', 'no', 'good', 'feel', 'and', 'they', 'them', 'socks',
#         'so', 'falling', 'down', 'lose', 'dont', 'breathable', 'recomend',
#         'elasticity', 'bunching'],
#        dtype='<U185'),
#  array(['it', 'just', 'is', 'of', 'the', 'this', 'not', 'expected', 'to',
#         'over', 'for', 'big', 'also', 'than', 'on', 'love', 'have', 'and',
#         'need', 'that', 'quality', 'are', 'one', 'my', 'itchy', 'light',
#         'mine', 'would', 'bigger', 'if', 'wear', 'think', 'nice', 'only',
#         'you', 'watch', 'today', 'do', 'be', 'all', 'bit', 'use', 'two',
#         'has', 'because', 'where', 'sturdy', 'recommend', 'everyday',
#         'band', 'looking', 'anyone', 'night', 'while', 'wrist',
#         'complaints', 'fact', 'leather', 'overall', 'tiny', 'amazing',
#         'numbers', 'face', 'opened', 'meet'],
#        dtype='<U185'),
#  array(['it', 'which', 'is', 'of', 'the', 'color', 'more', 'still', 'look',
#         'not', 'expected', 'to', 'size', 'up', 'very', 'too', 'big', 'than',
#         'good', 'soft', 'feel', 'neck', 'will', 'on', 'fit', 'have', 'and',
#         'need', 'that', 'great', 'ordered', 'shoulders', 'am', 'they',
#         'are', 'in', 'way', 'much', 'but', 'goes', 'comfortable', 'my',
#         'light', 'as', 'them', 'again', 'would', 'bigger', 'did', 'with',
#         'wear', 'or', 'lbs', 'get', 'you', 'could', 'your', 'so', 'these',
#         'pleasantly', 'play', 'be', 'shape', '10', 'slight', 'shirts',
#         'happy', 'tight', 'normal', 'probably', 'use', 'long', 'jeans',
#         'has', 'enough', 'new', 'me', 'does', 'mid', 'through', 'old',
#         'stretchy', 'might', 'down', 'tall', 'most', 'own', 'summer',
#         'looks', 'skin', 'deal', 'pull', 'line', 'photo', 'stretch',
#         'material', 'jacket', 'collar', 'winter', 'brown', 'appear',
#         'clothing', 'kill', 'fold', 'fairly', 'larger', 'largest', 'hole',
#         'fair', 'doesn', 'guide', 'decent', 'chest', 'height', 'expecting',
#         'green', 'evening', 'laundry', 'relaxed', 'section', '44',
#         'consider', 'solid', 'closely', 'tucking', 'nose', 'photos',
#         'split', 'fashioned', 'fearing', '190', 'firewood', 'casaba',
#         'bazooka', 'joe', 'unfolded', 'jaw', 'textured'],
#        dtype='<U185'),
#  array(['it', 'was', 'the', 'this', 'well', 'very', 'that', 'wanted', 'my',
#         'been', 'only', 'you', 'has', 'silver', 'within', 'thank',
#         'sterling', 'pendant', 'chain', 'budget', 'worthy', 'manufactured'],
#        dtype='<U185'),
#  array(['it', 'is', 'the', 'for', 'big', 'have', 'and', 'quality', 'but',
#         'been', 'like', 'last', 'time', 'long', 'bra', 'should', 'touch',
#         'pattern', 'meduim', '40dd'],
#        dtype='<U185'),
#  array(['it', 'just', 'was', 'of', 'the', 'color', 'expected', 'for', 'don',
#         'very', 'pretty', 'will', 'on', 'fit', 'love', 'and', 'that', '34',
#         'are', 'say', 'but', 'as', 'kind', 'waist', 'with', 'an', 'shirt',
#         'silver', 'me', 'pleased', 'cut', 'star', 'expect', 'okay',
#         'stretchy', 'extra', 'she', 'looking', 'sizing', 'rather', 'slim',
#         'gave', 'gorgeous', 'bronze', 'wasn', 'slick', 'studs',
#         'lightweight', 'wings', 'lyrcra', 'oil', 'dearly', 'junior',
#         'generous'],
#        dtype='<U185'),
#  array(['it', 'however', 'the', 'this', 'look', 'not', 'very', 'will',
#         'sweater', 'fit', 'love', 'have', 'what', 'nice', 'like', 'after',
#         'washed', 'yet', 'sure', 'washing', 'white', 'skull'],
#        dtype='<U185'),
#  array(['it', 'was', 'when', 'of', 'the', 'this', 'more', 'look', 'to',
#         'very', 'and', 'am', 'in', 'much', 'but', 'my', 'with', 'get',
#         'cheap', 'shoes', 'cute', 'liked', 'go', 'use', 'silver', 'me',
#         'person', 'didn', 'since', 'needed', 'wedding', 'gold', 'jewelry',
#         'minimal', 'bag', 'won', 'purse', 'comes', 'accessories', 'likely',
#         'recently', 'platinum', 'pashmina', 'bridesmaid', 'investment'],
#        dtype='<U185'),
#  array(['just', 'is', 'of', 'the', 'to', 'size', 'up', 'from', 'very',
#         'sizes', 'no', 'on', 'fit', 'perfectly', 'love', 'have', 'and',
#         'ordered', 'room', 'they', 'are', 'one', 'comfortable', 'my',
#         'bigger', 'there', 'or', 'like', 'so', 'do', 'around', 'black',
#         'off', 'run', 'order', 'normal', 'small', 'chance', 'foot', 'shoe',
#         'highly', 'plenty', 'already', 'toe', 'heel', 'flip', 'flops',
#         'blue', 'ones', 'recommended', 'teva', 'mush', 'hanging', 'note',
#         'original', 'colored', 'coral', 'personally', 'dreaded'],
#        dtype='<U185'),
#  array(['it', 'was', 'is', 'of', 'the', 'color', 'red', 'this', 'more',
#         'beautiful', 'not', 'to', 'size', 'over', 'for', 'don', 'very',
#         'too', 'big', 'good', 'soft', 'on', 'return', 'have', 'and',
#         'quality', 'ordered', 'in', 'way', 'can', 'much', 'my', 'them',
#         'did', 'with', 'nice', 'so', 'off', 'be', 'all', 'bit', 'had',
#         'tad', 'expect', 'how', 'shoe', 'short', 'know', 'sizing', 'toe',
#         'box', 'both', 'sandal', 'hoping', 'accurate', 'luck', 'sad',
#         'face', 'usual', 'sparkly', '37', '36'],
#        dtype='<U185'),
#  array(['before', 'of', 'the', 'more', 'to', 'then', 'over', 'for', 'will',
#         'on', 'perfectly', 'have', 'and', 'am', 'they', 'are', 'in', 'can',
#         'but', 'here', 'my', 'colors', 'if', 'been', 'wear', 'll', 'get',
#         'an', 'so', 'these', 'want', 'feet', 'high', 'around', 'wide',
#         'run', 'other', 'day', 'long', 'really', 're', 'take', 'never',
#         'because', 'actually', 'me', 'little', 'uncomfortable', 'fits',
#         'able', 'perfect', 'being', 'see', 'job', 'short', 'toe', 'bus',
#         'sandals', 'heels', 'legs', 'end', 'side', 'crocs', 'sandal',
#         'normally', 'stand', 'ran', 'wouldn', 'discovered', 'shunned',
#         'aching', 'cyprus', 'mild', 'pinching', 'toward', 'desk', 'convert'],
#        dtype='<U185'),
#  array(['just', 'about', 'which', 'is', 'when', 'online', 'of', 'the',
#         'picture', 'more', 'to', 'then', 'size', 'from', 'for', 'don',
#         'bad', 'idea', 'big', 'soon', 'have', 'and', 'that', '34', 'they',
#         'are', 'in', 'way', 'but', 'comfortable', 'my', 'as', 'buy',
#         'would', 'if', 'wear', 'think', 'fabric', 'said', 'even', 'you',
#         'pair', 'socks', 'cheap', 'so', 'feet', 'made', 'first', 'high',
#         'wide', 'off', 'all', 'now', '10', 'who', 'small', 'pants', 'going',
#         'into', 'store', 'right', 'got', 'little', 'narrow', 'mid', 'live',
#         'through', 'foot', 'isn', 'bright', 'see', 'come', 'she', 'loves',
#         'instead', 'hurt', 'seem', 'cause', 'their', 'maybe', 'turned',
#         'slightly', 'thicker', 'boot', 'white', 'disappointed', 'end',
#         'cups', '12', 'sold', 'rain', 'local', 'ran', 'plastic', 'colored',
#         'niece', 'zebra', 'range', 'stripes', 'footed', 'suction',
#         'opening', 'cafe', 'feed', 'vermont'],
#        dtype='<U185'),
#  array(['more', 'to', 'will', 'and', 'they', 'are', 'comfortable', 'colors',
#         'again', 'if', 'wear', 'even', 'last', 'these', 'order', 'find',
#         'lower', 'their', 'despite', 'tops', 'easy', 'prices'],
#        dtype='<U185'),
#  array(['super', 'to', 'well', 'no', 'fit', 'love', 'and', 'need', 'great',
#         'they', 'are', 'in', 'light', 'them', 'with', 'nice', 'so', 'these',
#         'cute', 'comfy', 'go', 'many', 'break', 'outfits'],
#        dtype='<U185'),
#  array(['it', 'was', 'is', 'this', 'more', 'not', 'to', 'size', 'well',
#         'very', 'pretty', 'try', 'fit', 'perfectly', 'have', 'and', '34',
#         'they', 'in', 'but', 'comfortable', 'my', 'even', 'there', 'were',
#         'or', 'could', 'another', 'so', 'had', 'because', 'right',
#         'decided', 'chance', 'bra', 'purchased', 'little', 'fits', 'didn',
#         'since', 'though', 'others', 'padding', 'otherwise', 'known',
#         'taking', 'few', 'name', 'something', 'women', 'doesn', 'cups',
#         'perhaps', 'recently', 'bind', 'carnival', 'lingerie', 'tug'],
#        dtype='<U185'),
#  array(['when', 'to', 'very', 'good', 'and', 'great', 'are', 'but',
#         'comfortable', 'as', 'them', 'again', 'or', 'these', 'time', 'im',
#         'order', 'every', 'find', 'shoe', 'picky', 'plan', 'sandal',
#         'replace', 'comes', 'cant', 'extras'],
#        dtype='<U185'),
#  array(['it', 'about', 'is', 'this', 'bad', 'will', 'on', 'have', 'and',
#         'say', 'comfortable', 'again', 'would', 'if', 'you', 'your', 'any',
#         'order', 'hide', 'material', 'body', 'sexy', 'anything', 'cannot',
#         'flaw', 'sooooo'],
#        dtype='<U185'),
#  array(['it', 'look', 'up', 'good', 'soft', 'love', 'and', 'my', 'nice',
#         'has', 'pants', 'most', 'construction', 'keeps', 'importantly',
#         'semi', 'gloss'],
#        dtype='<U185'),
#  array(['it', 'which', 'is', 'the', 'this', 'over', 'very', 'in', 'like',
#         'attractive', 'ring', 'order', 'same', 'might', 'earrings', 'lot',
#         'delicate', 'colour', 'prefer', 'dark', 'pale', 'green', 'matching',
#         'jade'],
#        dtype='<U185'),
#  array(['is', 'of', 'the', 'look', 'no', 'soft', 'and', 'great', 'they',
#         'them', 'with', 'wear', 'so', 'comfort', 'level', 're', 'far',
#         'casual', 'thick', 'though', 'their', 'both', 'feature', 'dressy',
#         'main', 'ensembles', 'signs'],
#        dtype='<U185'),
#  array(['it', 'was', 'fast', 'is', 'of', 'the', 'color', 'expected', 'to',
#         'size', 'good', 'love', 'and', 'quality', 'price', 'what', 'nice',
#         'description', 'liked', 'product', 'shipping', 'texture',
#         'according', 'combination', 'finishes'],
#        dtype='<U185'),
#  array(['just', 'is', 'ordering', 'the', 'more', 'not', 'to', 'size', 'for',
#         'at', 'also', 'feel', 'on', 'fit', 'love', 'have', 'and', 'that',
#         'large', 'am', 'some', 'they', 'are', 'in', 'but', 'my', 'as',
#         'them', 'buy', 'with', 'or', 'get', 'pair', 'these', 'feet', 'man',
#         'after', 'do', 'wide', 'things', 'run', 'hours', 'order', 'smaller',
#         'go', 'really', 'going', 'little', 'whole', 'he', 'his', 'whenever',
#         'slippers', 'give', 'their', 'christmas', 'next', 'family',
#         'larger', 'birthday', 'wonderful', '12', 'home', 'normally',
#         'spending', 'life', 'gifts', 'birthdays'],
#        dtype='<U185'),
#  array(['big', 'pretty', 'have', 'and', 'am', '34', 'but', 'with', 'its',
#         'could', 'bought', 'weight', 'small', 'little', 'gone', 'med',
#         '125', '32c'],
#        dtype='<U185'),
#  array(['about', 'of', 'the', 'to', 'well', 'for', 'and', 'great', 'price',
#         'they', 'are', 'comfortable', 'as', 'them', 'pair', 'these',
#         'shoes', 'especially', 'now', 've', 'use', 'durable', 'month',
#         'worn', 'casual', 'trail', 'plan', 'mountain', 'biking'],
#        dtype='<U185'),
#  array(['arrived', 'before', 'of', 'the', 'to', 'for', 'ordered', 'they',
#         'my', 'as', 'only', 'get', 'these', 'after', 'first', 'order',
#         'pairs', 'had', 'got', 'times', 'person', 'year', 'days', 'week',
#         'gift', 'else', 'finally', 'christmas', 'something', 'blue', 'next',
#         'arrival', 'saved', 'changed', 'date', 'thanksgiving', 'submitted',
#         'january'],
#        dtype='<U185'),
#  array(['it', 'was', 'of', 'the', 'look', 'not', 'to', 'size', 'too', 'on',
#         'fit', 'love', 'and', 'am', 'they', 'are', 'but', 'them', 'buy',
#         'would', 'bigger', 'like', 'so', 'be', 'bought', 'bit', 'tight',
#         'jeans', 'between', 'decided', 'better', 'me', 'little', 'how',
#         'skinny', 'keeping', 'legs', 'hoping', 'levi', '18', '16'],
#        dtype='<U185'),
#  array(['was', 'the', 'more', 'not', 'to', 'for', 'big', 'feel', 'on',
#         'have', 'and', 'am', 'they', 'are', 'can', 'but', 'them', 'buy',
#         'would', 'with', 'there', 'like', '50', 'out', 'these', 'any',
#         'shoes', 'alot', 'do', 'around', 'support', 'happy', 'other',
#         'really', 'never', 'had', 'brand', 'since', 'under', 'tried',
#         'cost', 'etc', 'provide', 'shock', 'nike', 'major', 'runner',
#         'recommendation', 'resistance', 'brooks', 'unlike', 'bough',
#         'discounts', 'adidas'],
#        dtype='<U185'),
#  array(['to', 'well', 'for', 'and', 'are', 'one', 'comfortable', 'my', 'as',
#         'buy', 'warm', 'so', 'these', 'leggings', 'pairs', 'had', 'myself',
#         'mom'],
#        dtype='<U185'),
#  array(['it', 'was', 'expected', 'size', 'big', 'than', 'great',
#         'comfortable', 'would', 'nice', 'time', 'order', 'smaller', 'bit',
#         'recommend', 'shoe', 'looking', 'half', 'next'],
#        dtype='<U185'),
#  array(['it', 'the', 'picture', 'this', 'to', 'don', 'back', 'have', 'and',
#         'in', 'but', 'came', 'would', 'been', 'think', 'nice', 'pay', 'so',
#         'want', 'ring', 'around', 'received', 'liked', 'product', 'three',
#         'broken', 'certainly', 'pieces', 'ship'],
#        dtype='<U185'),
#  array(['was', 'of', 'the', 'noticed', 'more', 'well', 'for', 'very',
#         'also', 'will', 'on', 'and', 'that', 'great', 'they', 'are', 'in',
#         'my', 'colors', 'them', 'buy', 'been', 'with', 'your', 'these',
#         'feet', 've', 'support', 'really', 'has', 'because', 'between',
#         'ever', 'best', 'owned', 'definitely', 'she', 'by', 'wow', 'give',
#         'slip', 'friend', 'few', 'flip', 'flops', 'sneakers', 'months',
#         'told', 'wasn', 'reasonably', 'priced', 'morning', 'immediately',
#         'condition', 'plantar', 'dramatically', 'improved', 'suffering',
#         'faciitis', 'kidding', 'upon', 'rising', 'alternate', 'tremendous',
#         'improvement'],
#        dtype='<U185'),
#  array(['it', 'about', 'of', 'to', 'very', 'too', 'love', 'have', 'that',
#         'some', 'they', 'are', 'comfortable', 'my', 'them', 'even', 'these',
#         'show', 'received', 'me', 'boots', 'people', 'compliments', 'asked'],
#        dtype='<U185'),
#  ...]

# %%
vectorizer.get_feature_names()[10000:100020]
# Out:
# ['bk',
#  'bk1089pink',
#  'bk3',
#  'bkacj',
#  'bkack',
#  'bkue',
#  'bkuz',
#  'bl',
#  'bl01',
#  'bl5250',
#  'bl8000',
#  'blaa',
#  'blaaaa',
#  'blab',
#  'blach',
#  'black',
#  'black2',
#  'black5',
#  'blackall',
#  'blackand',
#  'blackberries',
#  'blackberry',
#  'blackblack',
#  'blackbuena',
#  'blackcasio',
#  'blackcons',
#  'blackconsthe',
#  'blacked',
#  'blackened',
#  'blackening',
#  'blacker',
#  'blacket',
#  'blackevery',
#  'blackgood',
#  'blackgreywhite',
#  'blackhawk',
#  'blackhawks',
#  'blackhole',
#  'blacki',
#  'blackish',
#  'blackit',
#  'blacklight',
#  'blacklights',
#  'blacklist',
#  'blacklisting',
#  'blacklock',
#  'blackmail',
#  'blackmilk',
#  'blackmost',
#  'blackmy',
#  'blackness',
#  'blackout',
#  'blackouts',
#  'blackpairs',
#  'blacks',
#  'blacksugru',
#  'blackthey',
#  'blackthin',
#  'blacktop',
#  'blackupdate',
#  'blackwahk',
#  'blackwas',
#  'blackwhen',
#  'blackwould',
#  'blacl',
#  'bladder',
#  'bladders',
#  'blade',
#  'bladed',
#  'blades',
#  'blah',
#  'blahnik',
#  'blaim',
#  'blair',
#  'blaire',
#  'blakc',
#  'blake',
#  'blakely',
#  'blakey',
#  'blaklader',
#  'blam',
#  'blame',
#  'blamed',
#  'blaming',
#  'blanca',
#  'blancao',
#  'blance',
#  'blanche',
#  'blanco',
#  'blancos',
#  'bland',
#  'blander',
#  'blane',
#  'blank',
#  'blanked',
#  'blanket',
#  'blankets',
#  'blankie',
#  'blankies',
#  'blanks',
#  'blanquet',
#  'blare',
#  'blaring',
#  'blask',
#  'blasphemy',
#  'blass',
#  'blast',
#  'blasted',
#  'blaster',
#  'blasters',
#  'blasting',
#  'blasts',
#  'blatant',
#  'blatantly',
#  'blazard',
#  'blazars',
#  'blaze',
#  'blazer',
#  'blazerfor',
#  'blazers',
#  'blazes',
#  'blazin',
#  'blazing',
#  'blazoned',
#  'blazrer',
#  'blck',
#  'blclv015',
#  'ble',
#  'bleach',
#  'bleachable',
#  'bleached',
#  'bleacher',
#  'bleachers',
#  'bleaches',
#  'bleaching',
#  'bleachy',
#  'bleak',
#  'bleary',
#  'bleccch',
#  'blech',
#  'bleck',
#  'bled',
#  'bleed',
#  'bleeding',
#  'bleedingcons',
#  'bleeds',
#  'bleeep',
#  'bleep',
#  'bleepin',
#  'blegh',
#  'bleh',
#  'bleizer',
#  'blemish',
#  'blemished',
#  'blemishes',
#  'blemishing',
#  'blemishless',
#  'blend',
#  'blended',
#  'blender',
#  'blending',
#  'blends',
#  'bless',
#  'blessed',
#  'blessedly',
#  'blessing',
#  'blessings',
#  'blet',
#  'blew',
#  'bli',
#  'blimp',
#  'blind',
#  'blinded',
#  'blinders',
#  'blindfold',
#  'blindfolded',
#  'blinding',
#  'blindingly',
#  'blindly',
#  'blindness',
#  'blinds',
#  'bling',
#  'blingage',
#  'blinged',
#  'blingier',
#  'blinging',
#  'blings',
#  'blingthe',
#  'blingy',
#  'blink',
#  'blinked',
#  'blinker',
#  'blinking',
#  'blinks',
#  'blinky',
#  'blip',
#  'blipping',
#  'bliss',
#  'blissfully',
#  'blister',
#  'blistered',
#  'blisteriffic',
#  'blistering',
#  'blisters',
#  'blistersthe',
#  'blistery',
#  'blithely',
#  'blitz',
#  'blitzen',
#  'blitzens',
#  'blizzard',
#  'blizzards',
#  'blk',
#  'blkossom',
#  'bllazer',
#  'blllllllllllllllllllllllllllllllllllllllllluuue',
#  'bloat',
#  'bloated',
#  'bloating',
#  'bloats',
#  'bloaty',
#  'blob',
#  'blobby',
#  'blobs',
#  'bloch',
#  'block',
#  'blockage',
#  'blockbuster',
#  'blocked',
#  'blocker',
#  'blockers',
#  'blockier',
#  'blocking',
#  'blocks',
#  'blocky',
#  'blog',
#  'blogged',
#  'blogger',
#  'bloggers',
#  'blogs',
#  'blogspot',
#  'blogthis',
#  'bloke',
#  'blomm',
#  'blond',
#  'blonde',
#  'blood',
#  'blooded',
#  'bloodied',
#  'bloodshed',
#  'bloodstream',
#  'bloody',
#  'bloom',
#  'bloomer',
#  'bloomers',
#  'bloomery',
#  'bloomies',
#  'blooming',
#  'bloomingdales',
#  'blooms',
#  'bloomsday',
#  'blooper',
#  'bloopy',
#  'blos',
#  'blossom',
#  'blossoming',
#  'blossoms',
#  'blot',
#  'blotch',
#  'blotches',
#  'blotchy',
#  'blotted',
#  'blotting',
#  'blouse',
#  'blousebut',
#  'bloused',
#  'blouseis',
#  'blouseit',
#  'blouselove',
#  'blouseor',
#  'blouses',
#  'blousescosmetic',
#  'blousesthat',
#  'blouseswear',
#  'blousey',
#  'blousie',
#  'blousing',
#  'blouson',
#  'blousy',
#  'blow',
#  'blowdrying',
#  'blower',
#  'blowers',
#  'blowfish',
#  'blowfishshoes',
#  'blowhole',
#  'blowin',
#  'blowing',
#  'blowingly',
#  'blown',
#  'blowout',
#  'blowouts',
#  'blows',
#  'blu',
#  'blub',
#  'blubber',
#  'blubbery',
#  'bluchers',
#  'blucks',
#  'blue',
#  'blue2',
#  'bluebell',
#  'blueberry',
#  'bluechoice',
#  'bluefish',
#  'bluegrass',
#  'blueis',
#  'blueish',
#  'bluejean',
#  'bluejeans',
#  'blueness',
#  'bluer',
#  'bluerather',
#  'bluereminds',
#  'blues',
#  'bluesize',
#  'bluestone',
#  'bluetooth',
#  'bluff',
#  'bluffdust',
#  'bluffing',
#  'bluing',
#  'bluish',
#  'blunder',
#  'blundstone',
#  'blundstones',
#  'blunt',
#  'blunted',
#  'bluntly',
#  'bluoses',
#  'blur',
#  'blur33',
#  'blurb',
#  'blurbs',
#  'blurred',
#  'blurrier',
#  'blurring',
#  'blurry',
#  'blurted',
#  'blus',
#  'blusa',
#  'blusas',
#  'bluse',
#  'bluses',
#  'blush',
#  'blushed',
#  'blushes',
#  'blushing',
#  'blusters',
#  'blustery',
#  'blut',
#  'blvd',
#  'bm',
#  'bm6400',
#  'bm8180',
#  'bm8242',
#  'bmak',
#  'bmi',
#  'bmw',
#  'bmx',
#  'bmxer',
#  'bn0000',
#  'bnever',
#  'bng',
#  'bnot',
#  'bns',
#  'bo',
#  'boa',
#  'boabom',
#  'boar',
#  'board',
#  'boarded',
#  'boarder',
#  'boarderline',
#  'boarders',
#  'boarderthe',
#  'boarding',
#  'boardroom',
#  'boards',
#  'boardshort',
#  'boardshorts',
#  'boardwalk',
#  'boas',
#  'boast',
#  'boasted',
#  'boastful',
#  'boasting',
#  'boasts',
#  'boat',
#  'boater',
#  'boating',
#  'boatload',
#  'boatmen',
#  'boatneck',
#  'boats',
#  'boatshoes',
#  'boattail',
#  'boaty',
#  'bob',
#  'boba',
#  'bobafett',
#  'bobafetts',
#  'bobbi',
#  'bobbie',
#  'bobbies',
#  'bobbing',
#  'bobble',
#  'bobblehead',
#  'bobbles',
#  'bobbling',
#  'bobbly',
#  'bobby',
#  'bobbypin',
#  'bobidi',
#  'bobo',
#  'bobs',
#  'bobster',
#  'boby',
#  'bobysuits',
#  'boc',
#  'boca',
#  'bocelli',
#  'bod',
#  'boda',
#  'bodacious',
#  'bode',
#  'bodega',
#  'bodering',
#  'bodes',
#  'bodey',
#  'bodice',
#  'bodices',
#  'bodied',
#  'bodies',
#  'bodily',
#  'bodoy',
#  'bodunkadunk',
#  'body',
#  'bodyarmor',
#  'bodyart',
#  'bodybriefer',
#  'bodybuilder',
#  'bodybuilding',
#  'bodycon',
#  'bodycurves',
#  'bodyfat',
#  'bodyfit',
#  'bodyfitthe',
#  'bodyglide',
#  'bodyglove',
#  'bodyguard',
#  'bodyi',
#  'bodying',
#  'bodyj4you',
#  'bodyliked',
#  'bodyline',
#  'bodynot',
#  'bodys',
#  'bodyshape',
#  'bodyshaper',
#  'bodyshop',
#  'bodyslinky',
#  'bodyso',
#  'bodyspray',
#  'bodystep',
#  'bodystocking',
#  'bodystockings',
#  'bodystockingts',
#  'bodysuede',
#  'bodysuit',
#  'bodysuits',
#  'bodysurf',
#  'bodythere',
#  'bodythey',
#  'bodytone',
#  'bodyware',
#  'bodywash',
#  'bodywear',
#  'bodyweight',
#  'bodywould',
#  'bodywrappers',
#  'boeing',
#  'boetis',
#  'boff',
#  'bog',
#  'bogart',
#  'bogged',
#  'bogger',
#  'boggle',
#  'boggles',
#  'boggling',
#  'boggs',
#  'boght',
#  'bogling',
#  'bogo',
#  'bogota',
#  'bogous',
#  'bogs',
#  'bogus',
#  'boheimian',
#  'bohemian',
#  'bohmenian',
#  'boho',
#  'boil',
#  'boiled',
#  'boiler',
#  'boiling',
#  'boils',
#  'boing',
#  'boinging',
#  'boise',
#  'boit',
#  'boiught',
#  'boken',
#  'boks',
#  'bokwa',
#  'bold',
#  'boldblack',
#  'bolder',
#  'boldly',
#  'boldness',
#  'bolero',
#  'boleros',
#  'boleta',
#  'bolle',
#  'bollero',
#  'bolles',
#  'bollman',
#  'bollo',
#  'bollywood',
#  'bolo',
#  'bolsa',
#  'bolsillos',
#  'bolso',
#  'bolsos',
#  'bolster',
#  'bolt',
#  'bolted',
#  'boltom',
#  'bolts',
#  'bom',
#  'bomb',
#  'bombarded',
#  'bombardment',
#  'bombay',
#  'bombayfashions',
#  'bomber',
#  'bombif',
#  'bombing',
#  'bombproof',
#  'bombs',
#  'bombshell',
#  'bomer',
#  'bon',
#  'bonaire',
#  'bonanza',
#  'bond',
#  'bondage',
#  'bondcons',
#  'bonded',
#  'bonding',
#  'bondonkadonk',
#  'bone',
#  'bonechilling',
#  'boned',
#  'bonehead',
#  'boneless',
#  'bones',
#  'bonethis',
#  'boney',
#  'bonfire',
#  'bong',
#  'boniest',
#  'boning',
#  'bonions',
#  'bonita',
#  'bonitas',
#  'bonito',
#  'bonitos',
#  'bonk',
#  'bonkers',
#  'bonn',
#  'bonnaroo',
#  'bonnet',
#  'bonnie',
#  'bonsu',
#  'bonus',
#  'bonuses',
#  'bony',
#  'boo',
#  'boob',
#  'boobage',
#  'boobalicious',
#  'boobd',
#  'boobed',
#  'boobfat',
#  'boobicide',
#  'boobie',
#  'boobies',
#  'boobing',
#  'booble',
#  'boobles',
#  'boobmound',
#  'boobs',
#  'boobs3',
#  'boobsi',
#  'boobsthrough',
#  'boobtacular',
#  'boobular',
#  'boobwise',
#  'booby',
#  'boocuts',
#  'bood',
#  'boodshe',
#  'boody',
#  'booger',
#  'boogers',
#  'boogie',
#  'boogied',
#  'boogieing',
#  'boohoo',
#  'book',
#  'bookbag',
#  'bookcase',
#  'booked',
#  'bookends',
#  'bookfold',
#  'booklet',
#  'booklets',
#  'bookloads',
#  'bookmark',
#  'bookmarks',
#  'bookpack',
#  'books',
#  'bookshelf',
#  'bookshelves',
#  'booksi',
#  'bookstore',
#  'bookswhat',
#  'boom',
#  'boombalatty',
#  'boombox',
#  'boomer',
#  'boomerang',
#  'boomerangs',
#  'boomers',
#  'booming',
#  'boon',
#  'boondock',
#  'booney',
#  'boonie',
#  'boonies',
#  'booo',
#  'boooo',
#  'booooooo',
#  'booooooom',
#  'boooooooo',
#  'boooooooom',
#  'booot',
#  'boop',
#  'boors',
#  'boos',
#  'boost',
#  'boosted',
#  'booster',
#  'boosters',
#  'boosting',
#  'boosts',
#  'boot',
#  'bootable',
#  'bootand',
#  'bootandtimberland',
#  'bootay',
#  'bootboots',
#  'bootbottom',
#  'bootbut',
#  'bootcamp',
#  'bootcomfortable',
#  'bootcons',
#  'bootcouple',
#  'bootcut',
#  'bootcuts',
#  'booted',
#  'bootfit',
#  'bootfits',
#  'booth',
#  'boothas',
#  'boothighly',
#  'booths',
#  'bootie',
#  'booties',
#  'bootily',
#  'bootish',
#  'bootit',
#  'bootjack',
#  'bootlace',
#  'bootleg',
#  'bootleggers',
#  'bootlegging',
#  'bootmaker',
#  'bootpant',
#  'boots',
#  'boots2',
#  'bootsawesome',
#  'bootsi',
#  'bootslippers',
#  'bootsnj',
#  'bootsocks',
#  'bootsshe',
#  'bootssnaps',
#  'bootsso',
#  'bootssuper',
#  'bootsthey',
#  'bootstrap',
#  'bootsvery',
#  'bootswent',
#  'bootswhile',
#  'bootsyet',
#  'bootthe',
#  'bootwere',
#  'booty',
#  'bootyand',
#  'bootylicious',
#  'bootymy',
#  'bootys',
#  'boought',
#  'booze',
#  'bop',
#  'bopper',
#  'boppers',
#  'boppin',
#  'bopping',
#  'boppity',
#  'bora',
#  'borat',
#  'borax',
#  'bordeaux',
#  'borden',
#  'border',
#  'bordered',
#  'bordering',
#  'borderline',
#  'borderlines',
#  'borderlining',
#  'borders',
#  'bordo',
#  'bore',
#  'boreal',
#  'boreale',
#  'borealis',
#  'bored',
#  'boredom',
#  'borght',
#  'borgnine',
#  'boring',
#  'boringgg',
#  'boringness',
#  'borings',
#  'borke',
#  'borked',
#  'born',
#  'borne',
#  'borns',
#  'borrow',
#  'borrowed',
#  'borrowing',
#  'borrows',
#  'borrrrring',
#  'borsolino',
#  'borwn',
#  'bosc',
#  'boscov',
#  'boscovs',
#  'bose',
#  'bosmere',
#  'bosom',
#  'bosomed',
#  'bosoms',
#  'bosomy',
#  'boss',
#  'bosses',
#  'bossom',
#  'boston',
#  'bostonian',
#  'bostonians',
#  'bostons',
#  'bostony',
#  'bosu',
#  'bosum',
#  'bot',
#  'botanical',
#  'botany',
#  'botas',
#  'botched',
#  'both',
#  'bothby',
#  'bothdaily',
#  'bothdigital',
#  'bothe',
#  'bothedit',
#  'bother',
#  'botheration',
#  'bothered',
#  'bothering',
#  'bothers',
#  'bothersome',
#  'bothersomethe',
#  'bothh',
#  'bothi',
#  'bothwashed',
#  'botique',
#  'boto',
#  'botoom',
#  'botooms',
#  'botox',
#  'bots',
#  'bottem',
#  'botten',
#  'botth',
#  'botther',
#  'bottle',
#  'bottled',
#  'bottleis',
#  'bottleopener',
#  'bottlepocket',
#  'bottles',
#  'botto',
#  'bottom',
#  'bottom9',
#  'bottomare',
#  'bottome',
#  'bottomed',
#  'bottomi',
#  'bottomlength',
#  'bottomless',
#  'bottomline',
#  'bottomof',
#  'bottomoh',
#  'bottoms',
#  'bottomto',
#  'bottomwould',
#  'botton',
#  'bottonology',
#  'bottons',
#  'bottowm',
#  'bottum',
#  'botty',
#  'bouce',
#  'boucity',
#  'boudior',
#  'boudoir',
#  'bouffant',
#  'bougfht',
#  'bough',
#  'bough2',
#  'boughed',
#  'bought',
#  'bought18k',
#  'bought2',
#  'bought3',
#  'boughtanother',
#  'boughtboth',
#  'boughtcarter',
#  'boughtdenix',
#  'boughtdickies',
#  'boughten',
#  'boughthi',
#  'boughtplus',
#  'boughtt',
#  'boughtthe',
#  'boughtthis',
#  'boughtzenana',
#  'bougt',
#  'bougth',
#  'bougthe',
#  'bouhgt',
#  'bouht',
#  'bouight',
#  'boujght',
#  'boulder',
#  'bouldering',
#  'boulders',
#  'boulevard',
#  'bounce',
#  'bounceback',
#  'bouncecons',
#  'bounced',
#  'bouncers',
#  'bounces',
#  'bouncey',
#  'bounches',
#  'bouncier',
#  'bounciest',
#  'bouncin',
#  'bounciness',
#  'bouncing',
#  'bouncy',
#  'bound',
#  'boundaries',
#  'boundary',
#  'boundi',
#  'boundless',
#  'bounds',
#  'bouns',
#  'bountiful',
#  'bounty',
#  'bouqet',
#  'bouquet',
#  'bouquets',
#  'bourbon',
#  'bourdeaux',
#  'bourke',
#  'bouse',
#  'bouses',
#  'bout',
#  'boutght',
#  'bouth',
#  'bouthg',
#  'boutht',
#  'boutiguesque',
#  'boutik',
#  'boutique',
#  'boutiques',
#  'bouts',
#  'bouught',
#  'bouyancy',
#  'boverall',
#  'bovine',
#  'bow',
#  'bowed',
#  'bowel',
#  'bowels',
#  'bowen',
#  'bowerman',
#  'bowers',
#  'bowfish',
#  'bowi',
#  'bowie',
#  'bowing',
#  'bowl',
#  'bowled',
#  'bowler',
#  'bowling',
#  'bowls',
#  'bown',
#  'bows',
#  'bowtie',
#  'bowties',
#  'box',
#  'box1mm',
#  'box2',
#  'boxcar',
#  'boxcar2',
#  'boxcons',
#  'boxcutters',
#  'boxed',
#  'boxer',
#  'boxerbrief',
#  'boxerbriefs',
#  'boxeres',
#  'boxerjock',
#  'boxerjocks',
#  'boxers',
#  'boxerson',
#  'boxes',
#  'boxesfor',
#  'boxey',
#  'boxful',
#  'boxgreat',
#  'boxi',
#  'boxie',
#  'boxier',
#  'boxiness',
#  'boxing',
#  'boxs',
#  'boxsmaller',
#  'boxy',
#  'boy',
#  'boybriefs',
#  'boycott',
#  'boycotted',
#  'boycotting',
#  'boyfirend',
#  'boyfried',
#  'boyfriend',
#  'boyfriendit',
#  'boyfriends',
#  'boyfrinds',
#  'boyhood',
#  'boyish',
#  ...]

# %%
sorted_coef_indexes = np.argsort(lg.coef_[0])
feature_names = vectorizer.get_feature_names()
ten_highest = [feature_names[idx] for idx in sorted_coef_indexes[-10:]]
print(ten_highest)
ten_lowest = [feature_names[idx] for idx in sorted_coef_indexes[:10]]
print(ten_lowest)
# Out:
# ['highway', 'bandaids', 'definition', 'coolness', 'estimation', 'urging', 'konedog', 'elevated', 'facets', '117lbs']
# ['expressed', 'bearpaw', 'til', 'wink', 'accepted', 'membership', 'passing', 'firmer', 'halter', 'toms']

# %%
vectorizer.
# Out:
# '117lbs'

# %%
np.argmax?
