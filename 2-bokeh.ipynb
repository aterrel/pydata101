# %% [markdown]
# Introduction to Bokeh
# =====================
#
# In this tutorial we'll learn how to use Bokeh to build interactive visualizations viewable in a browser.  Generally this tutorial will have the following format
#
# `plotting` - Intermediate interface allowing control to all parts of a plot
#     - Vectorized attributes
#     - Toolbars
#     - Linked Brushing
#     - Interactivity
#
# Install
# -------
#
# This tutorial uses many different libraries that are all available with the [Anaconda Distribution](http://continuum.io/downloads). Once you have Anaconda install, please run these commands from a terminal:
#
# ```
# $ conda install -y bokeh
# ```
#
#
# <hr/>

# %% [markdown]
# # Introduction to [Bokeh](http://bokeh.pydata.org/)
#
# Provide a first-class visualization library for web-aware applications, without
# requiring web-level programming.
#
# Write a visualization python. Bokeh creates data descripors and a scenegraph consumed by BokehJS.
# This works in ipython notebook, creating static files and interacting with dynamic data sources.
#
# Bokeh includes pre-built schemas in bokeh.charts, a low-level composition interface (similar to matplotlib),
# a server for large and/or dynamic datasources and widgets for providing client-side realtime interaction.
#
# The non-JS framework also has prototypes in other languages (Scala, Julia...maybe R).
#
# **Note:** There are examples notebooks in bokeh/examples/plotting/notebooks. Start an ipython notebook server there to get more examples.
#
# [Gallery](http://bokeh.pydata.org/docs/gallery.html) --
# [tutorial](http://bokeh.pydata.org/tutorial/index.html) --
# [Documentation](http://bokeh.pydata.org/docs/user_guide.html) --
# [Repo](https://github.com/bokeh/bokeh)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Output
#
# Bokeh can output to html, a notebook, or just fragments for embedding in a web application.
#
# To start playing, we'll use the notebook. Later we will see the other types of output.

# %%
from bokeh.plotting import output_notebook  
output_notebook() # Tell Bokeh to output in an ipython notebook (other options later)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="120e589e-8a82-4b69-948b-3c9950742e63">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# <hr/>
#
# ## Plotting.py
#
# This is a mid-level interface, used by the charting library (and other parts of bokeh).   It can also be used directly.
# The basic idea: there is an active plot, and you are modifying it.

# %%
import numpy as np
from bokeh.plotting import *
N = 102
lin_arr = np.linspace(0, 4*np.pi, N)
sin_arr = np.sin(lin_arr)
cos_arr = np.cos(lin_arr)

# %% [markdown]
# <hr />
#
# ## Scatter Plots
#
# To begin with let's make a scatter plot.

# %%
p1 = figure()
p1.scatter(lin_arr, sin_arr, color="#FF00FF")
p1.scatter(lin_arr, cos_arr, color="green")
show(p1)
# Out:
#     <div class="plotdiv" id="27bb64a1-3173-4a46-89df-a687e5647cf9"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("27bb64a1-3173-4a46-89df-a687e5647cf9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '27bb64a1-3173-4a46-89df-a687e5647cf9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d6cf59cd-3dd4-4171-98bf-e13696f3ce88":{"roots":{"references":[{"attributes":{"formatter":{"id":"4712c249-3542-4fbd-b067-76e4bd555c19","type":"BasicTickFormatter"},"plot":{"id":"478f827f-1d86-46fc-9def-c081b018e4f1","subtype":"Figure","type":"Plot"},"ticker":{"id":"3dc71708-2245-4e46-8ea2-194c43cc2a4f","type":"BasicTicker"}},"id":"6e81fbd3-883c-405c-8978-537c775a487b","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"green"},"line_color":{"value":"green"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d8a37706-e09c-44eb-a15a-5e2db6063b7c","type":"Circle"},{"attribut
type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"ce8505cc-0ee8-45d6-9fc2-1afd71cce528","type":"Circle"},"selection_glyph":null},"id":"5ab48906-002e-4de7-a69f-3f5b74338ba4","type":"Gl ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[6]</strong>&gt;</code></p>

# %% [markdown]
# ### Other plotting things...
# There are lots of [glyph types](http://bokeh.pydata.org/docs/reference/plotting.html) and lots of [properties](http://bokeh.pydata.org/docs/user_guide/objects.html#userguide-objects-line-properties)...here is just a sample

# %% [markdown]
# <hr />
# ## Everything is vectorized
#
# While we have only been passing vectors for locations, we can do so for almost any parameter.
#
# Let's use the `cos_arr` to size the circles

# %%
p4 = figure()
p4.scatter(x=lin_arr, y=sin_arr, size=cos_arr**2*10)
show(p4)
# Out:
#     <div class="plotdiv" id="d32025ee-3f0a-40f8-86a3-a45c10227ff6"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d32025ee-3f0a-40f8-86a3-a45c10227ff6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd32025ee-3f0a-40f8-86a3-a45c10227ff6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"521cd7a5-499a-41d3-b92e-83351bbc7c6f":{"roots":{"references":[{"attributes":{"formatter":{"id":"7e0ef01c-cb64-4645-8081-5c38f8b8de83","type":"BasicTickFormatter"},"plot":{"id":"911c21f0-26c9-4635-a7fe-340ea09b3e47","subtype":"Figure","type":"Plot"},"ticker":{"id":"33f76a26-0c10-499f-bba9-45c0d1dfac59","type":"BasicTicker"}},"id":"f93382d2-47d9-4cf3-a55b-636d231102a6","type":"LinearAxis"},{"attributes":{"callback":null},"id":"2d9def6d-6c8e-4adc-bbec-0517b9aac60c","type":"DataRange1d"},{"attributes":{"overlay":{"id":"70f9b11a-6301-4622-b494-efcd8c084433","type":"BoxAnnotation"},"plot":{"id":"fc9a5c5d-fa73-4fbd-89fc-f68ddbc5671d","subtype":"Figure","type":"Plot"}},"id":"9d2b0787-4d43-4fe6-bf78-cb8dc5648b0e","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"6d61400e-30ee-4b70-9379-1d999726bb33","type":"BasicTickFormatter"},"plot":{"id":"c2cf2b3b-6054-442a-8147-83a14c2f3a10","subtype":"Figure","type":"Plot"},"ticker":{"id":"a4239216-0ded-435e-b65b-42dac57c73b2","type":"BasicTicker"}},"id":"4aa113d3-59e4-491c-ac1f-633d43251328","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"911c21f0-26c9-4635-a7fe-340ea09b3e47","subtype":"Figure","type":"Plot"},"ticker":{"id":"64adb285-191e-4f61-a7b8-c35d69e41137","type":"BasicTicker"}},"id":"ee26b7f5-50f9-4258-9c92-ede4297a311e","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"cbff86b9-ef56-4623-b396-416d825cab51","type":"BoxAnnotation"},{"attributes":{},"id":"33f76a26-0c10-499f-bba9-45c0d1dfac59","type":"BasicTicker"},{"attributes":{"plot":{"id":"478f827f-1d86-46fc-9def-c081b018e4f1","subtype":"Figure","type":"Plot"}},"id":"de42a6e8-6685-42c8-a59a-ed50655bd1b7","type":"ResetTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a0a9ce9c-f817-40d6-b2fc-5274a2d83816","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"911c21f0-26c9-4635-a7fe-340ea09b3e47","subtype":"Figure","type":"Plot"}},"id":"73af9791-ad71-4ae4-99b7-af714ceff6af","type":"ResetTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,0.12441951103325913,0.24883902206651826,0.3732585330997774,0.4976780441330365,0.6220975551662956,0.7465170661995548,0.8709365772328139,0.995356088266073,1.1197755992993321,1.2441951103325912,1.3686146213658503,1.4930341323991096,1.6174536434323687,1.7418731544656278,1.866292665498887,1.990712176532146,2.1151316875654054,2.2395511985986643,2.3639707096319236,2.4883902206651825,2.6128097316984418,2.7372292427317007,2.86164875376496,2.9860682647982193,3.110487775831478,3.2349072868647375,3.3593267978979964,3.4837463089312557,3.6081658199645146,3.732585330997774,3.8570048420310328,3.981424353064292,4.105843864097551,4.230263375130811,4.35468288616407,4.4791023971973285,4.603521908230587,4.727941419263847,4.852360930297106,4.976780441330365,5.101199952363625,5.2256194633968835,5.350038974430142,5.474458485463401,5.598877996496661,5.72329750752992,5.847717018563179,5.972136529596439,6.0965560406296975,6.220975551662956,6.345395062696215,6.469814573729475,6.594234084762734,6.718653595795993,6.843073106829252,6.967492617862511,7.09191212889577,7.216331639929029,7.340751150962289,7.465170661995548,7.589590173028807,7.7140096840620656,7.838429195095325,7.962848706128584,8.087268217161844,8.211687728195102,8.336107239228362,8.460526750261621,8.58494626129488,8.70936577232814,8.833785283361397,8.958204794394657,9.082624305427917,9.207043816461175,9.331463327494435,9.455882838527694 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[7]</strong>&gt;</code></p>

# %% [markdown]
# <hr/>
#
# Let's play with colors now. Brewer is a popular set of palletes. Here we pick one and then build a vector of colors for the plot.

# %%
from bokeh.palettes import brewer
print("Brewer Palettes:", brewer.keys())
print("Brewer Grey Palettes:", brewer["Greys"].keys())
palette = brewer["Greys"][9] + list(reversed(brewer["Greys"][9]))
colors = palette * int(len(lin_arr) / len(palette)) + palette[0:len(lin_arr) % len(palette)]
# Out:
# Brewer Palettes: dict_keys(['Spectral', 'Oranges', 'BuPu', 'RdYlBu', 'RdYlGn', 'OrRd', 'YlOrBr', 'PuBu', 'RdGy', 'RdPu', 'PRGn', 'YlOrRd', 'YlGn', 'YlGnBu', 'BuGn', 'GnBu', 'PuBuGn', 'Greens', 'Greys', 'PiYG', 'PuOr', 'PuRd', 'Reds', 'Purples', 'Blues', 'RdBu', 'BrBG'])
# Brewer Grey Palettes: dict_keys([3, 4, 5, 6, 7, 8, 9])

# %%
p5 = figure()
p5.scatter(x=lin_arr, y=sin_arr, size=cos_arr**2*10 + 5, fill_color=colors)
show(p5)
# Out:
#     <div class="plotdiv" id="749f4472-6410-457c-9631-3b28f0bf97d6"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("749f4472-6410-457c-9631-3b28f0bf97d6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '749f4472-6410-457c-9631-3b28f0bf97d6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"9f9e1bab-6fe7-4de9-a995-b4875d1f5281":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"af3d341d-b5c5-4b06-bf34-4078e174a91e","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"7e0ef01c-cb64-4645-8081-5c38f8b8de83","type":"BasicTickFormatter"},"plot":{"id":"911c21f0-26c9-4635-a7fe-340ea09b3e47","subtype":"Figure","type":"Plot"},"ticker":{"id":"33f76a26-0c10-499f-bba9-45c0d1dfac59","type":"BasicTicker"}},"id":"f93382d2-47d9-4cf3-a55b-636
...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[9]</strong>&gt;</code></p>

# %% [markdown]
# <hr/>
#
# ## Tools
#
# If you notice the bar at the top of the you see several places to interact with the plot.
#
# These are tools and there a many different tools built into the Bokeh.
#
# Let's take a look at HoverTools, but first we use Bokeh's data source which watches changes.

# %%
source = ColumnDataSource(
    data=dict(
        x=lin_arr,
        y=sin_arr,
        size=cos_arr**2*10 + 5,
        colors=colors
    )
)

# %%
from bokeh.models import HoverTool
from collections import OrderedDict

TOOLS="crosshair,pan,wheel_zoom,box_zoom,reset,hover,previewsave"
p6 = figure(title="Hoverful Scatter", tools=TOOLS)
p6.circle(x="x", y="y", size="size", source=source,
    fill_color="colors", fill_alpha=0.6, line_color=None)

hover = p6.select(dict(type=HoverTool))
hover.tooltips = OrderedDict([
    ("index", "$index"),
    ("(x,y)", "(@x, @y)"),
    ("size", "@size"),
    ("fill color", "$color[hex, swatch]:fill_color"),
])
show(p6)
# Out:
#     <div class="plotdiv" id="96b28b07-e013-4da3-9086-42ac5e18f2ef"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("96b28b07-e013-4da3-9086-42ac5e18f2ef");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '96b28b07-e013-4da3-9086-42ac5e18f2ef' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5b1eea57-9c39-4cfa-a34d-b4db8593fa0e":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"af3d341d-b5c5-4b06-bf34-4078e174a91e","type":"BoxAnnotation"},{"attributes":{"formatter":{"id":"7e0ef01c-cb64-4645-8081-5c38f8b8de83","type":"BasicTickFormatter"},"plot":{"id":"911c21f0-26c9-4635-a7fe-340ea09b3e47","subtype":"Figure","type":"Plot"},"ticker":{"id":"33f76a26-0c10-499f-bba9-45c0d1dfac59","type":"BasicTicker"}},"id":"f93382d2-47d9-4cf3-a55b-636d231102a6","type":"LinearAxis"},{"attributes":{"below":[{"id":"f93382d2-47d9-4cf3-a55b-636d231102a6","type":"LinearAxis"}],"left":[{"id":"0b90a075-2786-4f4e-866d-f5accd2bbcc8","type":"LinearAxis"}],"renderers":[{"id":"f93382d2-47d9-4cf3-a55b-636d231102a6","type":"LinearAxis"},{"id":"a8694f4b-4745-4895-8d20-e910031f3ce1","type":"Grid"},{"id":"0b90a075-2786-4f4e-866d-f5accd2bbcc8","type":"LinearAxis"},{"id":"ee26b7f5-50f9-4258-9c92-ede4297a311e","type":"Grid"},{"id":"cbff86b9-ef56-4623-b396-416d825cab51","type":"BoxAnnotation"},{"id":"37772282-62da-4e99-a47d-1d859e52e8f4","type":"GlyphRenderer"}],"tool_events":{"id":"79554afd-757e-45d1-941e-effde7228507","type":"ToolEvents"},"tools":[{"id":"19fcc8df-c08b-4aa4-9b82-5dbddf4c14bd","type":"PanTool"},{"id":"efb5ca15-328f-46d7-b8be-c2d1f4573612","type":"WheelZoomTool"},{"id":"754a3068-1b09-450e-8065-b31e1039c6f9","type":"BoxZoomTool"},{"id":"5cd93cb6-6859-46af-8264-9fd8a8f83712","type":"PreviewSaveTool"},{"id":"e27e70a4-73d1-463c-87fa-3c4103b370eb","type":"ResizeTool"},{"id":"73af9791-ad71-4ae4-99b7-af714ceff6af","type":"ResetTool"},{"id":"9ebf8c4f-2be0-4d11-8971-7f39a3c19dfc","type":"HelpTool"}],"x_range":{"id":"2d9def6d-6c8e-4adc-bbec-0517b9aac60c","type":"DataRange1d"},"y_range":{"id":"c8066e75-0379-43e7-8825-d8b6d7aa7b21","type":"DataRange1d"}},"id":"911c21f0-26c9-4635-a7fe-340ea09b3e47","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["x","size","y","fill_color"],"data":{"fill_color":["#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9","#bdbdbd","#969696","#737373","#525252","#252525","#000000","#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9","#bdbdbd","#969696","#737373","#525252","#252525","#000000","#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9","#bdbdbd","#969696","#737373","#525252","#252525","#000000","#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9","#bdbdbd","#969696","#737373","#525252","#252525","#000000","#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9","#bdbdbd","#969696","#737373","#525252","#252525","#000000","#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9"],"size":[15.0,14.84599499599833,14.393467000496344,13.6702926437973,12.721020913780137,11.60412884907684,10.388419236445031,9.148782221388007,7.961581925291557,6.899952262696125,6.029291745776234,5.403234805088819,5.060347801296216,5.021753260154907,5.289828682650054,5.8480600861760115,6.662059298919231,7.681682340073364,8.84411838942515,10.077759059601753,11.3066096160643,12.45497040486661,13.452100102858731,14.236573524788888,14.760065537663648,14.990327985667971,14.91317624111132,14.533363005885365,13.87428553551445,12.976544321383333,11.895442019201898,10.697576694719618,9.456739249572632,8.249367754043053,7.149838708931086,6.225885304233716,5.534424919066044,5.1180528971819665,5.00241858854006,5.194645 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[11]</strong>&gt;</code></p>

# %% [markdown]
# <hr />
#
# ## Linking two plots
#
# One of the best aspects of Bokeh is linking plots. We can link the brushing. This will allow you to select and pan with the plots both reacting to each other.

# %%
N = 300
x = np.linspace(0, 4*np.pi, N)
y1 = np.sin(x)
y2 = np.cos(x)

source = ColumnDataSource()
source.add(data=x, name='x')
source.add(data=y1, name='y1')
source.add(data=y2, name='y2')

TOOLS = "pan,wheel_zoom,box_zoom,reset,save,box_select,lasso_select"

s1 = figure(tools=TOOLS, plot_width=350, plot_height=350)
s1.scatter('x', 'y1', source=source)

# Linked brushing in Bokeh is expressed by sharing data sources between
# renderers. Note below that s2.scatter is called with the `source`
# keyword argument, and supplied with the same data source from s1.scatter
s2 = figure(tools=TOOLS, plot_width=350, plot_height=350, x_range=s1.x_range)
s2.scatter('x', 'y2', source=source, )

p = gridplot([[s1,s2]])
show(p)
# Out:
#     <div class="plotdiv" id="75a2c2d0-3066-4920-82de-d8f83b860142"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("75a2c2d0-3066-4920-82de-d8f83b860142");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid
774,0.4976780441330365,0.6220975551662956,0.7465170661995548,0.8709365772328139,0.995356088266073,1.1197755992993321,1.2441951103325912,1.3686146213658503,1.4930341323991096,1.6174536434323687,1.7418731544656278,1.866292665498887,1.990712176532146,2.1151316875654054,2.2395511985986643,2.3639707096319236,2.4883902206651825,2.6128097316984418,2.7372292427317007,2.86164875376496,2.9860682647982193,3.110487775831478,3.2349072868647375,3.3593267978979964,3.4837463089312557,3.60816 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[12]</strong>&gt;</code></p>

# %% [markdown]
# <hr />
#
# ## Basic interactivity
#
# Bokeh lets you use a Python update function to update your plots.
#
# In IPython notebook we can use the interactive widgets provided by the notebook. One can also use Flask or Bokeh-server to embed in outside the notebook.

# %%
x = np.linspace(0, 2*np.pi, 2000)
y = np.sin(x)

source = ColumnDataSource(data=dict(x=x, y=y))

p = figure(title="simple line example", plot_height=300, plot_width=600)
p.line(x, y, color="#2222aa", line_width=3, source=source, name="foo")

# %%
from IPython.html.widgets import interact
@interact(f=["sin", "cos", "tan"], w=(0,100), A=(1,10), phi=(0, 10, 0.1))
def update(f, w=1, A=1, phi=0):
    if   f == "sin": func = np.sin
    elif f == "cos": func = np.cos
    elif f == "tan": func = np.tan
    source.data['y'] = A * func(w * x + phi)
    source.push_notebook()
# Out:
# /Users/aterrel/miniconda/envs/pydata101/lib/python3.5/site-packages/ipykernel/__main__.py:8: BokehDeprecationWarning: bokeh.models.sources.push_notebook was deprecated in Bokeh 0.11.0; please use bokeh.io.push_notebook instead

# %%
show(p)
# Out:
#     <div class="plotdiv" id="042089b7-89dd-49de-adc8-5cab29fbdb41"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("042089b7-89dd-49de-adc8-5cab29fbdb41");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '042089b7-89dd-49de-adc8-5cab29fbdb41' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5249a0c6-db5e-4878-a1b1-9d9b7d56bf1e":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"af3d341d-b5c5-4b06-bf34-4078e174a91e","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x","size","y","fill_color"],"data":{"fill_color":["#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9","#bdbdbd","#969696","#737373","#525252","#252525","#000000","#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9","#bdbdbd","#969696","#737373","#525252","#252525","#000000","#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9","#bdbdbd","#969696","#737373","#525252","#252525","#000000","#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9","#bdbdbd","#969696","#737373","#525252","#252525","#000000","#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9","#bdbdbd","#969696","#737373","#525252","#252525","#000000","#000000","#252525","#525252","#737373","#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff","#ffffff","#f0f0f0","#d9d9d9"],"size":[15.0,14.

#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="33d78278-022b-4531-a6e5-1f30932f0b8f">Loading BokehJS ...</span>
#     </div>
# /Users/aterrel/miniconda/envs/pydata101/lib/python3.5/site-packages/ipykernel/__main__.py:13: BokehDeprecationWarning: bokeh.charts.chart.show was deprecated in Bokeh 0.11; please use bokeh.io.show instead
#     <div class="plotdiv" id="d9a6e454-ba92-417c-9a82-bb331b2028be"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d9a6e454-ba92-417c-9a82-bb331b2028be");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd9a6e454-ba92-417c-9a82-bb331b2028be' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f5aa2c02-6057-4a69-bca9-87b6bbe11f86":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"af3d341d-b5c5-4b06-bf34-4078e174a91e","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"9cf875a5-d127-42ec-87a3-9b971e2e367e","type":"ColumnDataSource"},"glyph":{"id":"8af3378e-fe68-4ff1-97f7-40be7882003d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3634ec50-35da-4779-84c1-a5330e7ef258","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","height","x","width","line_alpha","fill_alpha","color","y"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[11.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.07000000000000006],"x":["-0.994"],"y":[5.5]}},"id":"d6b40529-18d6-41d7-b8a4-01d4187bbe88","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f501853a-3e87-4c99-aa24-90f6756ce72d","type":"Rect"},{"attributes":{"callback":null,"column_names":["line_color","height","x","width","line_alpha","fill_alpha","color","y"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[35.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.07000000000000006],"x":["0.565"],"y":[17.5]}},"id":"ddd09290-f1b2-45ee-b249-846775dcdca9","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"be1091e2-67dd-437b-8c13-6b966549bb89","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["line_color","height","x","width","line_alpha","fill_alpha","color","y"],"data":{"chart_index":["None"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"line_alpha":[1.0],"line_color":["black"],"width":[0.07000000000000006],"x":["1.54"],"y":[0.0]}},"id":"baf458ff-a71a-42ca-8d6f-7e63a43cbd63","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"d6efc403-2cf2-427e-bbd0-1f33f1bfc6c8","subtype":"Figure","type":"Plot"},"ticker":{"id":"ff7d83cd-7a5e-4f9d-b594-ccbab9a6a5dc","type":"BasicTicker"}},"id":"042d76ea-4f9f-4d41-a624-4c101ec00f52","type":"Grid"},{"attributes":{"plot":{"id":"7d4b2333-e7d8-463c-aea9-cfadfd5a3222","subtype":"Figure","type":"Plot"},"ticker":{"id":"faaf50fd-ec25-4a1c-a061-25574f486343","type":"BasicTicker"}},"id":"a098acb8-42ea-440f-a226-a2128287d77f","type":"Grid"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6abcfe9d-5050-40ce-95d0-9f2240635a57","type":"Rect"},{"attributes":{"data_source":{"id":"09c411c2-1ac5-4b8f-974e-ccbb02598e4c","type":"ColumnDataSource"},"glyph":{"id":"f501853a-3e87-4c99-aa24-90f6756ce72d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"44e64c14-6f85-4b22-ad4e-b970de0c05e6","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a0a9ce9c-f817-40d6-b2fc-5274a2d83816","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"9bc47492-cccd-460b-8435-3737d2678795","type":"ColumnDataSource"},"glyph":{"id":"cea257f4-500f-4991-87ea-d9d938ea9dab","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyp ...
